# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
# %matplotlib inline

import seaborn as sns

# %%
# data = "https://www.kaggle.com/datasets/ashydv/housing-dataset"
data = "https://archive.ics.uci.edu/static/public/2/adult.zip"

# %%
# !wget $data

# %%
columns=('age',
'workclass',
'fnlwgt',
'education',
'education-num',
'marital-status',
'occupation',
'relationship',
'race',
'sex',
'capital-gain',
'capital-loss',
'hours-per-week',
'native-country',
'income')

# %%
df_full_train = pd.read_csv("adult.data", names=columns)
df_test = pd.read_csv("adult.test", names=columns, skiprows=1)

# %%
df_full_train.shape, df_test.shape
# Out:
# ((32561, 15), (16281, 15))

# %%
32561 + 16281
# Out:
# 48842

# %%
df_full_train.head()
# Out:
#    age          workclass  fnlwgt   education  education-num  \
# 0   39          State-gov   77516   Bachelors             13
# 1   50   Self-emp-not-inc   83311   Bachelors             13
# 2   38            Private  215646     HS-grad              9
# 3   53            Private  234721        11th              7
# 4   28            Private  338409   Bachelors             13
#
#         marital-status          occupation    relationship    race      sex  \
# 0        Never-married        Adm-clerical   Not-in-family   White     Male
# 1   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 4   Married-civ-spouse      Prof-specialty            Wife   Black   Female
#
#    capital-gain  capital-loss  hours-per-week  native-country  income
# 0          2174             0              40   United-States   <=50K
# 1             0             0              13   United-States   <=50K
# 2             0             0              40   United-States   <=50K
# 3             0             0              40   United-States   <=50K
# 4             0             0              40            Cuba   <=50K

# %%
df_full_train.dtypes
# Out:
# age                int64
# workclass         object
# fnlwgt             int64
# education         object
# education-num      int64
# marital-status    object
# occupation        object
# relationship      object
# race              object
# sex               object
# capital-gain       int64
# capital-loss       int64
# hours-per-week     int64
# native-country    object
# income            object
# dtype: object

# %%
df_full_train.columns = df_full_train.columns.str.lower().str.replace('-', '_')

# %%
df_test.columns = df_test.columns.str.lower().str.replace('-', '_')

# %%
df_test.head()
# Out:
#    age   workclass  fnlwgt      education  education_num       marital_status  \
# 0   25     Private  226802           11th              7        Never-married
# 1   38     Private   89814        HS-grad              9   Married-civ-spouse
# 2   28   Local-gov  336951     Assoc-acdm             12   Married-civ-spouse
# 3   44     Private  160323   Some-college             10   Married-civ-spouse
# 4   18           ?  103497   Some-college             10        Never-married
#
#            occupation relationship    race      sex  capital_gain  \
# 0   Machine-op-inspct    Own-child   Black     Male             0
# 1     Farming-fishing      Husband   White     Male             0
# 2     Protective-serv      Husband   White     Male             0
# 3   Machine-op-inspct      Husband   Black     Male          7688
# 4                   ?    Own-child   White   Female             0
#
#    capital_loss  hours_per_week  native_country   income
# 0             0              40   United-States   <=50K.
# 1             0              50   United-States   <=50K.
# 2             0              40   United-States    >50K.
# 3             0              40   United-States    >50K.
# 4             0              30   United-States   <=50K.

# %%
categorical_columns = list(df_full_train.dtypes[df_full_train.dtypes == 'object'].index)

# %%
categorical_columns
# Out:
# ['workclass',
#  'education',
#  'marital_status',
#  'occupation',
#  'relationship',
#  'race',
#  'sex',
#  'native_country',
#  'income']

# %%
numerical_columns = list(df_full_train.dtypes[df_full_train.dtypes != 'object'].index)

# %%
numerical_columns
# Out:
# ['age',
#  'fnlwgt',
#  'education_num',
#  'capital_gain',
#  'capital_loss',
#  'hours_per_week']

# %%
for col in categorical_columns:
    df_full_train[col] = df_full_train[col].str.lower().str.strip().str.replace('-', '_')
    df_test[col] = df_test[col].str.lower().str.strip().str.replace('-', '_')

# %%
df_full_train.head()
# Out:
#    age         workclass  fnlwgt  education  education_num  \
# 0   39         state_gov   77516  bachelors             13
# 1   50  self_emp_not_inc   83311  bachelors             13
# 2   38           private  215646    hs_grad              9
# 3   53           private  234721       11th              7
# 4   28           private  338409  bachelors             13
#
#        marital_status         occupation   relationship   race     sex  \
# 0       never_married       adm_clerical  not_in_family  white    male
# 1  married_civ_spouse    exec_managerial        husband  white    male
# 2            divorced  handlers_cleaners  not_in_family  white    male
# 3  married_civ_spouse  handlers_cleaners        husband  black    male
# 4  married_civ_spouse     prof_specialty           wife  black  female
#
#    capital_gain  capital_loss  hours_per_week native_country income
# 0          2174             0              40  united_states  <=50k
# 1             0             0              13  united_states  <=50k
# 2             0             0              40  united_states  <=50k
# 3             0             0              40  united_states  <=50k
# 4             0             0              40           cuba  <=50k

# %%
df_full_train['workclass'].unique()
# Out:
# array(['state_gov', 'self_emp_not_inc', 'private', 'federal_gov',
#        'local_gov', '?', 'self_emp_inc', 'without_pay', 'never_worked'],
#       dtype=object)

# %%
df_test.head()
# Out:
#    age  workclass  fnlwgt     education  education_num      marital_status  \
# 0   25    private  226802          11th              7       never_married
# 1   38    private   89814       hs_grad              9  married_civ_spouse
# 2   28  local_gov  336951    assoc_acdm             12  married_civ_spouse
# 3   44    private  160323  some_college             10  married_civ_spouse
# 4   18          ?  103497  some_college             10       never_married
#
#           occupation relationship   race     sex  capital_gain  capital_loss  \
# 0  machine_op_inspct    own_child  black    male             0             0
# 1    farming_fishing      husband  white    male             0             0
# 2    protective_serv      husband  white    male             0             0
# 3  machine_op_inspct      husband  black    male          7688             0
# 4                  ?    own_child  white  female             0             0
#
#    hours_per_week native_country  income
# 0              40  united_states  <=50k.
# 1              50  united_states  <=50k.
# 2              40  united_states   >50k.
# 3              40  united_states   >50k.
# 4              30  united_states  <=50k.

# %%
for col in df_full_train.columns:
    print(col)
    print(df_full_train[col].unique()[:5])
    print()
# Out:
# age
# [39 50 38 53 28]
#
# workclass
# ['state_gov' 'self_emp_not_inc' 'private' 'federal_gov' 'local_gov']
#
# fnlwgt
# [ 77516  83311 215646 234721 338409]
#
# education
# ['bachelors' 'hs_grad' '11th' 'masters' '9th']
#
# education_num
# [13  9  7 14  5]
#
# marital_status
# ['never_married' 'married_civ_spouse' 'divorced' 'married_spouse_absent'
#  'separated']
#
# occupation
# ['adm_clerical' 'exec_managerial' 'handlers_cleaners' 'prof_specialty'
#  'other_service']
#
# relationship
# ['not_in_family' 'husband' 'wife' 'own_child' 'unmarried']
#
# race
# ['white' 'black' 'asian_pac_islander' 'amer_indian_eskimo' 'other']
#
# sex
# ['male' 'female']
#
# capital_gain
# [ 2174     0 14084  5178  5013]
#
# capital_loss
# [   0 2042 1408 1902 1573]
#
# hours_per_week
# [40 13 16 45 50]
#
# native_country
# ['united_states' 'cuba' 'jamaica' 'india' '?']
#
# income
# ['<=50k' '>50k']

# %%
sns.histplot(df_full_train['income'])
# Out:
# <Axes: xlabel='income', ylabel='Count'>

# %%
df_full_train['income>50k'] = (df_full_train['income'] == '>50k').astype(int)
df_test['income>50k'] = (df_test['income'] == '>50k.').astype(int)

# %%
df_test
# Out:
#        age     workclass  fnlwgt     education  education_num  \
# 0       25       private  226802          11th              7
# 1       38       private   89814       hs_grad              9
# 2       28     local_gov  336951    assoc_acdm             12
# 3       44       private  160323  some_college             10
# 4       18             ?  103497  some_college             10
# ...    ...           ...     ...           ...            ...
# 16276   39       private  215419     bachelors             13
# 16277   64             ?  321403       hs_grad              9
# 16278   38       private  374983     bachelors             13
# 16279   44       private   83891     bachelors             13
# 16280   35  self_emp_inc  182148     bachelors             13
#
#            marital_status         occupation    relationship  \
# 0           never_married  machine_op_inspct       own_child
# 1      married_civ_spouse    farming_fishing         husband
# 2      married_civ_spouse    protective_serv         husband
# 3      married_civ_spouse  machine_op_inspct         husband
# 4           never_married                  ?       own_child
# ...                   ...                ...             ...
# 16276            divorced     prof_specialty   not_in_family
# 16277             widowed                  ?  other_relative
# 16278  married_civ_spouse     prof_specialty         husband
# 16279            divorced       adm_clerical       own_child
# 16280  married_civ_spouse    exec_managerial         husband
#
#                      race     sex  capital_gain  capital_loss  hours_per_week  \
# 0                   black    male             0             0              40
# 1                   white    male             0             0              50
# 2                   white    male             0             0              40
# 3                   black    male          7688             0              40
# 4                   white  female             0             0              30
# ...                   ...     ...           ...           ...             ...
# 16276               white  female             0             0              36
# 16277               black    male             0             0              40
# 16278               white    male             0             0              50
# 16279  asian_pac_islander    male          5455             0              40
# 16280               white    male             0             0              60
#
#       native_country  income  income>50k
# 0      united_states  <=50k.           0
# 1      united_states  <=50k.           0
# 2      united_states   >50k.           1
# 3      united_states   >50k.           1
# 4      united_states  <=50k.           0
# ...              ...     ...         ...
# 16276  united_states  <=50k.           0
# 16277  united_states  <=50k.           0
# 16278  united_states  <=50k.           0
# 16279  united_states  <=50k.           0
# 16280  united_states   >50k.           1
#
# [16281 rows x 16 columns]

# %%
df_full_train = df_full_train.replace('?', np.nan)
df_test = df_test.replace('?', np.nan)

# %%
df_full_train.isnull().sum()
# Out:
# age                  0
# workclass         1836
# fnlwgt               0
# education            0
# education_num        0
# marital_status       0
# occupation        1843
# relationship         0
# race                 0
# sex                  0
# capital_gain         0
# capital_loss         0
# hours_per_week       0
# native_country     583
# income               0
# income>50k           0
# dtype: int64

# %%
df_full_train = df_full_train.dropna()
df_test = df_test.dropna()

# %%
df_full_train.shape[0], df_test.shape[0]
# Out:
# (30162, 15060)

# %%
30162 + 15060
# Out:
# 45222

# %% [markdown]
# ### Setting up validation framework

# %%
from sklearn.model_selection import train_test_split

# %%
df_train, df_val = train_test_split(df_full_train, test_size=0.2, random_state=11)

# %%
df_train.shape[0], df_val.shape[0], df_test.shape[0]
# Out:
# (24129, 6033, 15060)

# %%
df_train = df_train.reset_index(drop=True)
df_val = df_val.reset_index(drop=True)

# %%
df_train
# Out:
#        age         workclass  fnlwgt     education  education_num  \
# 0       59           private  252714       hs_grad              9
# 1       40           private  308027       hs_grad              9
# 2       36           private  186110  some_college             10
# 3       31           private  117963       hs_grad              9
# 4       38           private  165930       hs_grad              9
# ...    ...               ...     ...           ...            ...
# 24124   52           private  117700       hs_grad              9
# 24125   49         state_gov  122177  some_college             10
# 24126   43  self_emp_not_inc   75435       hs_grad              9
# 24127   65           private  361721     assoc_voc             11
# 24128   29           private  244566       hs_grad              9
#
#            marital_status         occupation   relationship  \
# 0      married_civ_spouse  machine_op_inspct        husband
# 1                 widowed      other_service      unmarried
# 2      married_civ_spouse   transport_moving        husband
# 3           never_married  handlers_cleaners  not_in_family
# 4      married_civ_spouse       craft_repair        husband
# ...                   ...                ...            ...
# 24124            divorced       adm_clerical  not_in_family
# 24125  married_civ_spouse  machine_op_inspct        husband
# 24126            divorced       craft_repair      unmarried
# 24127  married_civ_spouse   transport_moving        husband
# 24128            divorced  machine_op_inspct      unmarried
#
#                      race     sex  capital_gain  capital_loss  hours_per_week  \
# 0                   white    male             0             0              30
# 1                   black  female             0             0              40
# 2                   white    male             0             0              40
# 3                   white    male             0             0              60
# 4                   white    male             0             0              40
# ...                   ...     ...           ...           ...             ...
# 24124               white  female             0             0              40
# 24125               white    male             0             0              40
# 24126  amer_indian_eskimo    male             0             0              30
# 24127               white    male             0             0              20
# 24128               white    male             0             0              40
#
#       native_country income  income>50k
# 0              italy  <=50k           0
# 1      united_states  <=50k           0
# 2      united_states  <=50k           0
# 3      united_states  <=50k           0
# 4      united_states  <=50k           0
# ...              ...    ...         ...
# 24124  united_states  <=50k           0
# 24125  united_states   >50k           1
# 24126  united_states  <=50k           0
# 24127  united_states  <=50k           0
# 24128  united_states  <=50k           0
#
# [24129 rows x 16 columns]

# %%
y_train = df_train['income>50k']
y_val = df_val['income>50k']
y_test = df_test['income>50k']

# %%
del df_train['income']
del df_val['income']
del df_test['income']

del df_train['income>50k']
del df_val['income>50k']
del df_test['income>50k']

del df_train['fnlwgt']
del df_val['fnlwgt']
del df_test['fnlwgt']

# %% [markdown]
# ### Exploratory data analysis

# %%
# Checking the default high income rate in our dataset
df_full_train['income>50k'].value_counts(normalize=True)
# Out:
# 0    0.751078
# 1    0.248922
# Name: income>50k, dtype: float64

# %%
global_high_income_rate = df_full_train['income>50k'].mean()
global_high_income_rate
# Out:
# 0.24892248524633645

# %%
df_train.dtypes[df_train.dtypes == 'object'].index
# Out:
# Index(['workclass', 'education', 'marital_status', 'occupation',
#        'relationship', 'race', 'sex', 'native_country'],
#       dtype='object')

# %%
df_train.dtypes[df_train.dtypes != 'object'].index
# Out:
# Index(['age', 'education_num', 'capital_gain', 'capital_loss',
#        'hours_per_week'],
#       dtype='object')

# %%
categorical = ['workclass', 'education', 'marital_status', 'occupation',
       'relationship', 'race', 'sex', 'native_country']

# %%
numerical = ['age', 'capital_gain', 'capital_loss','hours_per_week']

# %%
categorical
# Out:
# ['workclass',
#  'education',
#  'marital_status',
#  'occupation',
#  'relationship',
#  'race',
#  'sex',
#  'native_country']

# %%
numerical
# Out:
# ['age', 'capital_gain', 'capital_loss', 'hours_per_week']

# %%
df_full_train['education_num'].unique()
# Out:
# array([13,  9,  7, 14,  5, 10, 12,  4, 16, 11, 15,  3,  6,  1,  8,  2])

# %%
df_full_train['education'].unique()
# Out:
# array(['bachelors', 'hs_grad', '11th', 'masters', '9th', 'some_college',
#        'assoc_acdm', '7th_8th', 'doctorate', 'assoc_voc', 'prof_school',
#        '5th_6th', '10th', 'preschool', '12th', '1st_4th'], dtype=object)

# %%
len(df_full_train['education_num'].unique())
# Out:
# 16

# %%
len(df_full_train['education'].unique())
# Out:
# 16

# %%
df_full_train[categorical].nunique()
# Out:
# workclass          7
# education         16
# marital_status     7
# occupation        14
# relationship       6
# race               5
# sex                2
# native_country    41
# dtype: int64

# %%
df_full_train.head()
# Out:
#    age         workclass  fnlwgt  education  education_num  \
# 0   39         state_gov   77516  bachelors             13
# 1   50  self_emp_not_inc   83311  bachelors             13
# 2   38           private  215646    hs_grad              9
# 3   53           private  234721       11th              7
# 4   28           private  338409  bachelors             13
#
#        marital_status         occupation   relationship   race     sex  \
# 0       never_married       adm_clerical  not_in_family  white    male
# 1  married_civ_spouse    exec_managerial        husband  white    male
# 2            divorced  handlers_cleaners  not_in_family  white    male
# 3  married_civ_spouse  handlers_cleaners        husband  black    male
# 4  married_civ_spouse     prof_specialty           wife  black  female
#
#    capital_gain  capital_loss  hours_per_week native_country income  \
# 0          2174             0              40  united_states  <=50k
# 1             0             0              13  united_states  <=50k
# 2             0             0              40  united_states  <=50k
# 3             0             0              40  united_states  <=50k
# 4             0             0              40           cuba  <=50k
#
#    income>50k
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0

# %%
df_full_train.workclass.unique()
# Out:
# array(['state_gov', 'self_emp_not_inc', 'private', 'federal_gov',
#        'local_gov', 'self_emp_inc', 'without_pay'], dtype=object)

# %%
df_full_train[df_full_train['workclass'] == 'federal_gov']['income>50k'].mean()
# Out:
# 0.3870625662778367

# %%
df_full_train[df_full_train['workclass'] == 'state_gov']['income>50k'].mean()
# Out:
# 0.2689601250977326

# %%
df_full_train[df_full_train['workclass'] == 'local_gov']['income>50k'].mean()
# Out:
# 0.2946298984034833

# %%
df_full_train.education.unique()
# Out:
# array(['bachelors', 'hs_grad', '11th', 'masters', '9th', 'some_college',
#        'assoc_acdm', '7th_8th', 'doctorate', 'assoc_voc', 'prof_school',
#        '5th_6th', '10th', 'preschool', '12th', '1st_4th'], dtype=object)

# %%
df_full_train[df_full_train['education'] == 'doctorate']['income>50k'].mean()
# Out:
# 0.7466666666666667

# %%
from IPython.display import display

# %%
for c in categorical:
    df_group = df_full_train.groupby(c)['income>50k'].agg(['mean', 'count'])
    df_group['diff'] = df_group['mean'] - global_high_income_rate
    df_group['risk'] = df_group['mean'] / global_high_income_rate
    display(df_group)
    print()
    print()
# Out:
#                       mean  count      diff      risk
# workclass
# federal_gov       0.387063    943  0.138140  1.554952
# local_gov         0.294630   2067  0.045707  1.183621
# private           0.218792  22286 -0.030130  0.878957
# self_emp_inc      0.558659   1074  0.309737  2.244310
# self_emp_not_inc  0.285714   2499  0.036792  1.147804
# state_gov         0.268960   1279  0.020038  1.080498
# without_pay       0.000000     14 -0.248922  0.000000
#                   mean  count      diff      risk
# education
# 10th          0.071951    820 -0.176971  0.289051
# 11th          0.056298   1048 -0.192625  0.226166
# 12th          0.076923    377 -0.171999  0.309024
# 1st_4th       0.039735    151 -0.209187  0.159628
# 5th_6th       0.041667    288 -0.207256  0.167388
# 7th_8th       0.062837    557 -0.186086  0.252435
# 9th           0.054945    455 -0.193977  0.220732
# assoc_acdm    0.253968   1008  0.005046  1.020270
# assoc_voc     0.263198   1307  0.014276  1.057350
# bachelors     0.421491   5044  0.172568  1.693262
# doctorate     0.746667    375  0.497744  2.999595
# hs_grad       0.164329   9840 -0.084593  0.660162
# masters       0.564229   1627  0.315306  2.266684
# preschool     0.000000     45 -0.248922  0.000000
# prof_school   0.749077    542  0.500155  3.009280
# some_college  0.200060   6678 -0.048863  0.803704
#                            mean  count      diff      risk
# marital_status
# divorced               0.107262   4214 -0.141661  0.430903
# married_af_spouse      0.476190     21  0.227268  1.913007
# married_civ_spouse     0.454959  14065  0.206037  1.827714
# married_spouse_absent  0.083784    370 -0.165139  0.336586
# never_married          0.048324   9726 -0.200598  0.194133
# separated              0.070288    939 -0.178635  0.282367
# widowed                0.096735    827 -0.152187  0.388616
#                        mean  count      diff      risk
# occupation
# adm_clerical       0.133835   3721 -0.115087  0.537657
# armed_forces       0.111111      9 -0.137811  0.446368
# craft_repair       0.225310   4030 -0.023612  0.905142
# exec_managerial    0.485220   3992  0.236298  1.949283
# farming_fishing    0.116279    989 -0.132643  0.467130
# handlers_cleaners  0.061481   1350 -0.187441  0.246990
# machine_op_inspct  0.124619   1966 -0.124304  0.500632
# other_service      0.041096   3212 -0.207827  0.165095
# priv_house_serv    0.006993    143 -0.241929  0.028093
# prof_specialty     0.448489   4038  0.199567  1.801723
# protective_serv    0.326087    644  0.077164  1.309994
# sales              0.270647   3584  0.021725  1.087276
# tech_support       0.304825    912  0.055902  1.224576
# transport_moving   0.202926   1572 -0.045996  0.815218
#                     mean  count      diff      risk
# relationship
# husband         0.455669  12463  0.206746  1.830565
# not_in_family   0.106523   7726 -0.142399  0.427938
# other_relative  0.039370    889 -0.209552  0.158162
# own_child       0.014330   4466 -0.234592  0.057570
# unmarried       0.066314   3212 -0.182609  0.266404
# wife            0.493599   1406  0.244676  1.982942
#                         mean  count      diff      risk
# race
# amer_indian_eskimo  0.118881    286 -0.130041  0.477583
# asian_pac_islander  0.277095    895  0.028172  1.113178
# black               0.129925   2817 -0.118997  0.521951
# other               0.090909    231 -0.158013  0.365210
# white               0.263718  25933  0.014796  1.059438
#             mean  count      diff      risk
# sex
# female  0.113678   9782 -0.135244  0.456681
# male    0.313837  20380  0.064915  1.260782
#                                 mean  count      diff      risk
# native_country
# cambodia                    0.388889     18  0.139966  1.562289
# canada                      0.336449    107  0.087526  1.351620
# china                       0.294118     68  0.045195  1.181563
# columbia                    0.035714     56 -0.213208  0.143476
# cuba                        0.271739     92  0.022817  1.091662
# dominican_republic          0.029851     67 -0.219072  0.119920
# ecuador                     0.148148     27 -0.100774  0.595158
# el_salvador                 0.090000    100 -0.158922  0.361558
# england                     0.348837     86  0.099915  1.401389
# france                      0.444444     27  0.195522  1.785473
# germany                     0.343750    128  0.094828  1.380952
# greece                      0.275862     29  0.026940  1.108225
# guatemala                   0.047619     63 -0.201303  0.191301
# haiti                       0.095238     42 -0.153684  0.382601
# holand_netherlands          0.000000      1 -0.248922  0.000000
# honduras                    0.083333     12 -0.165589  0.334776
# hong                        0.315789     19  0.066867  1.268626
# hungary                     0.230769     13 -0.018153  0.927073
# india                       0.400000    100  0.151078  1.606926
# iran                        0.428571     42  0.179649  1.721706
# ireland                     0.208333     24 -0.040589  0.836941
# italy                       0.352941     68  0.104019  1.417876
# jamaica                     0.125000     80 -0.123922  0.502164
# japan                       0.389831     59  0.140908  1.566072
# laos                        0.117647     17 -0.131275  0.472625
# mexico                      0.054098    610 -0.194824  0.217330
# nicaragua                   0.060606     33 -0.188316  0.243474
# outlying_us(guam_usvi_etc)  0.000000     14 -0.248922  0.000000
# peru                        0.066667     30 -0.182256  0.267821
# philippines                 0.319149    188  0.070226  1.282122
# poland                      0.196429     56 -0.052494  0.789115
# portugal                    0.117647     34 -0.131275  0.472625
# puerto_rico                 0.110092    109 -0.138831  0.442273
# scotland                    0.181818     11 -0.067104  0.730421
# south                       0.197183     71 -0.051739  0.792147
# taiwan                      0.452381     42  0.203458  1.817357
# thailand                    0.176471     17 -0.072452  0.708938
# trinadad&tobago             0.111111     18 -0.137811  0.446368
# united_states               0.254327  27504  0.005404  1.021710
# vietnam                     0.078125     64 -0.170797  0.313853
# yugoslavia                  0.375000     16  0.126078  1.506493

# %% [markdown]
# ### Feature importance : Mutual information

# %%
from sklearn.metrics import mutual_info_score

# %%
mutual_info_score(df_full_train.age, df_full_train['income>50k'])
# Out:
# 0.0675671582497318

# %%
mutual_info_score(df_full_train['race'], df_full_train['income>50k'])
# Out:
# 0.0057490412634228485

# %%
def mutual_info_highincome_score(series):
    return mutual_info_score(series, df_full_train['income>50k'])

# %%
mi = df_full_train[categorical].apply(mutual_info_highincome_score)
mi.sort_values(ascending=False)
# Out:
# relationship      0.115186
# marital_status    0.109150
# education         0.064736
# occupation        0.064597
# sex               0.025928
# workclass         0.011856
# native_country    0.006466
# race              0.005749
# dtype: float64

# %% [markdown]
# ### Feature importance : Correlation

# %%
df_full_train[numerical].corrwith(df_full_train['income>50k']).sort_values(ascending=False)
# Out:
# age               0.241998
# hours_per_week    0.229480
# capital_gain      0.221196
# capital_loss      0.150053
# dtype: float64

# %% [markdown]
# #### One hot encoding

# %%
from sklearn.feature_extraction import DictVectorizer

# %%
# df_full_train['age']

# %%
train_dicts = df_train[categorical + numerical].to_dict(orient='records')
train_dicts
# Out:
# [{'workclass': 'private',
#   'education': 'hs_grad',
#   'marital_status': 'married_civ_spouse',
#   'occupation': 'machine_op_inspct',
#   'relationship': 'husband',
#   'race': 'white',
#   'sex': 'male',
#   'native_country': 'italy',
#   'age': 59,
#   'capital_gain': 0,
#   'capital_loss': 0,
#   'hours_per_week': 30},
#  {'workclass': 'private',
#   'education': 'hs_grad',
#   'marital_status': 'widowed',
#   'occupation': 'other_service',
#   'relationship': 'unmarried',
#   'race': 'black',
#   'sex': 'female',
#   'native_country': 'united_states',
#   'age': 40,
#   'capital_gain': 0,
#   'capital_loss': 0,
#   'hours_per_week': 40},
#  {'workclass': 'private',
#   'education': 'some_college',
#   'marital_status': 'married_civ_spouse',
#   'occupation': 'transport_moving',
#   'relationship': 'husband',
#   'race': 'white',
#   'sex': 'male',
#   'native_country': 'united_states',
#   'age': 36,
#   'capital_gain': 0,
#   'capital_loss': 0,
#   'hours_per_week': 40},
#  {'workclass': 'private',
#   'education': 'hs_grad',
#   'marital_status': 'never_married',
#   'occupation': 'handlers_cleaners',
#   'relationship': 'not_in_family',
#   'race': 'white',
#   'sex': 'male',
#   'native_country': 'united_states',
#   'age': 31,
#   'capital_gain': 0,
#   'capital_loss': 0,
#   'hours_per_week': 60},
#  {'workclass': 'private',
#   'education': 'hs_grad',
#   'marital_status': 'married_civ_spouse',
#   'occupation': 'craft_repair',
#   'relationship': 'husband',
#   'race': 'white',
#   'sex': 'male',
#   'native_country': 'united_states',
#   'age': 38,
#   'capital_gain': 0,
#   'capital_loss': 0,
#   'hours_per_week': 40},
#  {'workclass': 'private',
#   'education': 'bachelors',
#   'marital_status': 'never_married',
#   'occupation': 'exec_managerial',
#   'relationship': 'not_in_family',
#   'race': 'black',
#   'sex': 'female',
#   'native_country': 'united_states',
#   'age': 43,
#   'capital_gain': 0,
#   'capital_loss': 0,
#   'hours_per_week': 50},
#  {'workclass': 'state_gov',
#   'education': '7th_8th',
#   'marital_status': 'widowed',
#   'occupation': 'handlers_cleaners',
#   'relationship': 'not_in_family',
#   'race': 'white',
#   'sex': 'female',
#   'native_country': 'united_states',
#   'age': 74,
#   'capital_gain': 0,
#   'capital_loss': 0,
#   'hours_per_week': 20},
#  {'workclass': 'self_emp_not_inc',
#   'education': '5th_6th',
#   'marital_status': 'married_civ_spouse',
#   'occupation': 'sales',
#   'relationship': 'husband',
#   'race': 'white',
#   'sex': 'male',
#   'native_country': 'italy',
#   'age': 47,
#   'capital_gain': 0,
#   'capital_loss': 0,
#   'hours_per_week': 55},
#  {'workclass': 'private',
#   'education': 'assoc_acdm',
#   'marital_status': 'divorced',
#   'occupation': 'adm_clerical',
#   'relationship': 'own_child',
#   'race': 'white',
#   'sex': 'female',
#   'native_country': 'united_states',
#   'age': 34,
#   'capital_gain': 0,
#   'capital_loss': 0,
#   'hours_per_week': 35},
#  {'workclass': 'private',
#   'education': '10th',
#   'marital_status': 'married_spouse_absent',
#   'occupation': 'transport_moving',
#   'relationship': 'not_in_family',
#   'race': 'black',
#   'sex': 'male',
#   'native_country': 'united_states',
#   'age': 47,
#   'capital_gain': 0,
#   'capital_loss': 0,
#   'hours_per_week': 45},
#  {'workclass': 'private',
#   'education': 'hs_grad',
#   'marital_status': 'never_married',
#   'occupation': 'craft_repair',
#   'relationship': 'not_in_family',
#   'race': 'white',
#   'sex': 'male',
#   'native_country': 'united_states',
#   'age': 27,
#   'capital_gain': 0,
#   'capital_loss': 0,
#   'hours_per_week': 40},
#  {'workclass': 'private',
#   'education': 'hs_grad',
#   'marital_status': 'married_civ_spouse',
#   'occupation': 'machine_op_inspct',
#   'relationship': 'husband',
#   'race': 'white',
#   'sex': 'male',
#   'native_country': 'united_states',
#   'age': 32,
#   'capital_gain': 0,
#   'capital_loss': 0,
#   'hours_per_week': 40},
#  {'workclass': 'private',
#   'education': 'some_college',
#   'marital_status': 'never_married',
#   'occupation': 'other_service',
#   'relationship': 'own_child',
#   'race': 'white',
#   'sex': 'male',
#   'native_country': 'united_states',
#   'age': 18,
#   'capital_gain': 0,
#   'capital_loss': 0,
#   'hours_per_week': 20},
#  {'workclass': 'private',
#   'education': 'some_college',
#   'marital_status': 'married_civ_spouse',
#   'occupation': 'exec_managerial',
#   'relationship': 'husband',
#   'race': 'white',
#   'sex': 'male',
#   'native_country': 'united_states',
#   'age': 49,
#   'capital_gain': 0,
#   'capital_loss': 0,
#   'hours_per_week': 50},
#  {'workclass': 'private',
#   'education': 'hs_grad',
#   'marital_status': 'never_married',
#   'occupation': 'handlers_cleaners',
#   'relationship': 'own_child',
#   'race': 'white',
#   'sex': 'male',
#   'native_country': 'united_states',
#   'age': 19,
#   'capital_gain': 0,
#   'capital_loss': 0,
#   'hours_per_week': 25},
#  {'workclass': 'private',
#   'education': 'hs_grad',
#   'marital_status': 'married_civ_spouse',
#   'occupation': 'tech_support',
#   'relationship': 'husband',
#   'race': 'asian_pac_islander',
#   'sex': 'male',
#   'native_country': 'philippines',
#   'age': 64,
#   'capital_gain': 0,
#   'capital_loss': 0,
#   'hours_per_week': 60},
#  {'workclass': 'private',
#   'education': 'some_college',
#   'marital_status': 'never_married',
#   'occupation': 'other_service',
#   'relationship': 'own_child',
#   'race': 'white',
#   'sex': 'male',
#   'native_country': 'united_states',
#   'age': 21,
#   'capital_gain': 0,
#   'capital_loss': 0,
#   'hours_per_week': 25},
#  {'workclass': 'private',
#   'education': 'hs_grad',
#   'marital_status': 'married_civ_spouse',
#   'occupation': 'exec_managerial',
#   'relationship': 'wife',
#   'race': 'white',
#   'sex': 'female',
#   'native_country': 'united_states',
#   'age': 28,
#   'capital_gain': 0,
#   'capital_loss': 0,
#   'hours_per_week': 45},
#  {'workclass': 'private',
#   'education': '7th_8th',
#   'marital_status': 'divorced',
#   'occupation': 'other_service',
#   'relationship': 'unmarried',
#   'race': 'white',
#   'sex': 'female',
#   'native_country': 'united_states',
#   'age': 28,
#   'capital_gain': 0,
#   'capital_loss': 0,
#   'hours_per_week': 50},
#  {'workclass': 'private',
#   'education': 'masters',
#   'marital_status': 'married_civ_spouse',
#   'occupation': 'exec_managerial',
#   'relationship': 'husband',
#   'race': 'white',
#   'sex': 'male',
#   'native_country': 'united_states',
#   'age': 58,
#   'capital_gain': 0,
#   'capital_loss': 0,
#   'hours_per_week': 40},
#  {'workclass': 'private',
#   'education': 'bachelors',
#   'marital_status': 'married_civ_spouse',
#   'occupation': 'exec_managerial',
#   'relationship': 'husband',
#   'race': 'white',
#   'sex': 'male',
#   'native_country': 'united_states',
#   'age': 53,
#   'capital_gain': 0,
#   'capital_loss': 0,
#   'hours_per_week': 44},
#  {'workclass': 'private',
#   'education': 'some_college',
#   'marital_status': 'married_civ_spouse',
#   'occupation': 'adm_clerical',
#   'relationship': 'husband',
#   'race': 'white',
#   'sex': 'male',
#   'native_country': 'united_states',
#   'age': 45,
#   'capital_gain': 0,
#   'capital_loss': 0,
#   'hours_per_week': 40},
#  {'workclass': 'private',
#   'education': 'bachelors',
#   'marital_status': 'married_civ_spouse',
#   'occupation': 'prof_specialty',
#   'relationship': 'husband',
#   'race': 'white',
#   'sex': 'male',
#   'native_country': 'united_states',
#   'age': 45,
#   'capital_gain': 0,
#   'capital_loss': 0,
#   'hours_per_week': 42},
#  {'workclass': 'private',
#   'education': '7th_8th',
#   'marital_status': 'married_civ_spouse',
#   'occupation': 'craft_repair',
#   'relationship': 'husband',
#   'race': 'black',
#   'sex': 'male',
#   'native_country': 'united_states',
#   'age': 47,
#   'capital_gain': 0,
#   'capital_loss': 0,
#   'hours_per_week': 60},
#  {'workclass': 'self_emp_not_inc',
#   'education': 'bachelors',
#   'marital_status': 'married_civ_spouse',
#   'occupation': 'prof_specialty',
#   'relationship': 'husband',
#   'race': 'white',
#   'sex': 'male',
#   'native_country': 'united_states',
#   'age': 32,
#   'capital_gain': 7688,
#   'capital_loss': 0,
#   'hours_per_week': 40},
#  {'workclass': 'private',
#   'education': 'hs_grad',
#   'marital_status': 'married_civ_spouse',
#   'occupation': 'craft_repair',
#   'relationship': 'husband',
#   'race': 'white',
#   'sex': 'male',
#   'native_country': 'united_states',
#   'age': 42,
#   'capital_gain': 0,
#   'capital_loss': 1672,
#   'hours_per_week': 40},
#  {'workclass': 'state_gov',
#   'education': 'hs_grad',
#   'marital_status': 'separated',
#   'occupation': 'craft_repair',
#   'relationship': 'not_in_family',
#   'race': 'white',
#   'sex': 'male',
#   'native_country': 'united_states',
#   'age': 37,
#   'capital_gain': 0,
#   'capital_loss': 0,
#   'hours_per_week': 44},
#  {'workclass': 'private',
#   'education': 'assoc_voc',
#   'marital_status': 'married_civ_spouse',
#   'occupation': 'sales',
#   'relationship': 'husband',
#   'race': 'white',
#   'sex': 'male',
#   'native_country': 'united_states',
#   'age': 45,
#   'capital_gain': 0,
#   'capital_loss': 1977,
#   'hours_per_week': 50},
#  {'workclass': 'private',
#   'education': 'hs_grad',
#   'marital_status': 'married_civ_spouse',
#   'occupation': 'craft_repair',
#   'relationship': 'husband',
#   'race': 'white',
#   'sex': 'male',
#   'native_country': 'united_states',
#   'age': 38,
#   'capital_gain': 0,
#   'capital_loss': 0,
#   'hours_per_week': 40},
#  {'workclass': 'private',
#   'education': 'bachelors',
#   'marital_status': 'married_civ_spouse',
#   'occupation': 'exec_managerial',
#   'relationship': 'husband',
#   'race': 'white',
#   'sex': 'male',
#   'native_country': 'iran',
#   'age': 41,
#   'capital_gain': 0,
#   'capital_loss': 0,
#   'hours_per_week': 50},
#  {'workclass': 'private',
#   'education': 'assoc_acdm',
#   'marital_status': 'married_civ_spouse',
#   'occupation': 'prof_specialty',
#   'relationship': 'husband',
#   'race': 'white',
#   'sex': 'male',
#   'native_country': 'united_states',
#   'age': 38,
#   'capital_gain': 0,
#   'capital_loss': 0,
#   'hours_per_week': 40},
#  {'workclass': 'private',
#   'education': 'some_college',
#   'marital_status': 'never_married',
#   'occupation': 'adm_clerical',
#   'relationship': 'not_in_family',
#   'race': 'white',
#   'sex': 'female',
#   'native_country': 'united_states',
#   'age': 47,
#   'capital_gain': 0,
#   'capital_loss': 0,
#   'hours_per_week': 40},
#  {'workclass': 'private',
#   'education': 'some_college',
#   'marital_status': 'never_married',
#   'occupation': 'sales',
#   'relationship': 'own_child',
#   'race': 'white',
#   'sex': 'female',
#   'native_country': 'united_states',
#   'age': 24,
#   'capital_gain': 0,
#   'capital_loss': 0,
#   'hours_per_week': 40},
#  {'workclass': 'self_emp_not_inc',
#   'education': 'hs_grad',
#   'marital_status': 'married_civ_spouse',
#   'occupation': 'sales',
#   'relationship': 'husband',
#   'race': 'white',
#   'sex': 'male',
#   'native_country': 'united_states',
#   'age': 37,
#   'capital_gain': 0,
#   'capital_loss': 0,
#   'hours_per_week': 45},
#  {'workclass': 'private',
#   'education': '9th',
#   'marital_status': 'never_married',
#   'occupation': 'other_service',
#   'relationship': 'own_child',
#   'race': 'white',
#   'sex': 'male',
#   'native_country': 'united_states',
#   'age': 31,
#   'capital_gain': 0,
#   'capital_loss': 0,
#   'hours_per_week': 40},
#  {'workclass': 'private',
#   'education': 'some_college',
#   'marital_status': 'widowed',
#   'occupation': 'adm_clerical',
#   'relationship': 'unmarried',
#   'race': 'white',
#   'sex': 'female',
#   'native_country': 'united_states',
#   'age': 31,
#   'capital_gain': 0,
#   'capital_loss': 0,
#   'hours_per_week': 40},
#  {'workclass': 'private',
#   'education': 'hs_grad',
#   'marital_status': 'divorced',
#   'occupation': 'transport_moving',
#   'relationship': 'not_in_family',
#   'race': 'white',
#   'sex': 'male',
#   'native_country': 'united_states',
#   'age': 37,
#   'capital_gain': 0,
#   'capital_loss': 0,
#   'hours_per_week': 40},
#  {'workclass': 'local_gov',
#   'education': 'bachelors',
#   'marital_status': 'divorced',
#   'occupation': 'prof_specialty',
#   'relationship': 'not_in_family',
#   'race': 'white',
#   'sex': 'female',
#   'native_country': 'united_states',
#   'age': 37,
#   'capital_gain': 0,
#   'capital_loss': 0,
#   'hours_per_week': 36},
#  {'workclass': 'private',
#   'education': 'some_college',
#   'marital_status': 'married_civ_spouse',
#   'occupation': 'adm_clerical',
#   'relationship': 'wife',
#   'race': 'white',
#   'sex': 'female',
#   'native_country': 'united_states',
#   'age': 25,
#   'capital_gain': 0,
#   'capital_loss': 0,
#   'hours_per_week': 40},
#  {'workclass': 'private',
#   'education': '11th',
#   'marital_status': 'married_civ_spouse',
#   'occupation': 'transport_moving',
#   'relationship': 'husband',
#   'race': 'black',
#   'sex': 'male',
#   'native_country': 'united_states',
#   'age': 42,
#   'capital_gain': 0,
#   'capital_loss': 0,
#   'hours_per_week': 40},
#  {'workclass': 'private',
#   'education': 'assoc_acdm',
#   'marital_status': 'never_married',
#   'occupation': 'adm_clerical',
#   'relationship': 'not_in_family',
#   'race': 'white',
#   'sex': 'female',
#   'native_country': 'cuba',
#   'age': 46,
#   'capital_gain': 0,
#   'capital_loss': 0,
#   'hours_per_week': 47},
#  {'workclass': 'private',
#   'education': 'assoc_voc',
#   'marital_status': 'never_married',
#   'occupation': 'tech_support',
#   'relationship': 'not_in_family',
#   'race': 'white',
#   'sex': 'male',
#   'native_country': 'united_states',
#   'age': 38,
#   'capital_gain': 0,
#   'capital_loss': 0,
#   'hours_per_week': 50},
#  {'workclass': 'private',
#   'education': 'hs_grad',
#   'marital_status': 'married_civ_spouse',
#   'occupation': 'machine_op_inspct',
#   'relationship': 'husband',
#   'race': 'white',
#   'sex': 'male',
#   'native_country': 'united_states',
#   'age': 33,
#   'capital_gain': 0,
#   'capital_loss': 0,
#   'hours_per_week': 40},
#  {'workclass': 'private',
#   'education': 'assoc_voc',
#   'marital_status': 'divorced',
#   'occupation': 'prof_specialty',
#   'relationship': 'unmarried',
#   'race': 'white',
#   'sex': 'female',
#   'native_country': 'united_states',
#   'age': 41,
#   'capital_gain': 0,
#   'capital_loss': 0,
#   'hours_per_week': 43},
#  {'workclass': 'private',
#   'education': 'some_college',
#   'marital_status': 'never_married',
#   'occupation': 'other_service',
#   'relationship': 'own_child',
#   'race': 'white',
#   'sex': 'female',
#   'native_country': 'united_states',
#   'age': 22,
#   'capital_gain': 0,
#   'capital_loss': 0,
#   'hours_per_week': 25},
#  {'workclass': 'local_gov',
#   'education': 'hs_grad',
#   'marital_status': 'widowed',
#   'occupation': 'other_service',
#   'relationship': 'not_in_family',
#   'race': 'white',
#   'sex': 'female',
#   'native_country': 'united_states',
#   'age': 53,
#   'capital_gain': 0,
#   'capital_loss': 0,
#   'hours_per_week': 30},
#  {'workclass': 'private',
#   'education': 'hs_grad',
#   'marital_status': 'never_married',
#   'occupation': 'adm_clerical',
#   'relationship': 'unmarried',
#   'race': 'white',
#   'sex': 'female',
#   'native_country': 'united_states',
#   'age': 54,
#   'capital_gain': 0,
#   'capital_loss': 0,
#   'hours_per_week': 40},
#  {'workclass': 'local_gov',
#   'education': 'assoc_voc',
#   'marital_status': 'widowed',
#   'occupation': 'prof_specialty',
#   'relationship': 'unmarried',
#   'race': 'black',
#   'sex': 'female',
#   'native_country': 'united_states',
#   'age': 42,
#   'capital_gain': 0,
#   'capital_loss': 0,
#   'hours_per_week': 40},
#  {'workclass': 'self_emp_not_inc',
#   'education': 'hs_grad',
#   'marital_status': 'divorced',
#   'occupation': 'craft_repair',
#   'relationship': 'not_in_family',
#   'race': 'white',
#   'sex': 'male',
#   'native_country': 'united_states',
#   'age': 41,
#   'capital_gain': 0,
#   'capital_loss': 0,
#   'hours_per_week': 40},
#  {'workclass': 'local_gov',
#   'education': 'bachelors',
#   'marital_status': 'never_married',
#   'occupation': 'prof_specialty',
#   'relationship': 'not_in_family',
#   'race': 'white',
#   'sex': 'female',
#   'native_country': 'united_states',
#   'age': 33,
#   'capital_gain': 0,
#   'capital_loss': 0,
#   'hours_per_week': 50},
#  {'workclass': 'private',
#   'education': 'hs_grad',
#   'marital_status': 'divorced',
#   'occupation': 'exec_managerial',
#   'relationship': 'unmarried',
#   'race': 'white',
#   'sex': 'female',
#   'native_country': 'united_states',
#   'age': 36,
#   'capital_gain': 0,
#   'capital_loss': 0,
#   'hours_per_week': 50},
#  {'workclass': 'self_emp_not_inc',
#   'education': 'hs_grad',
#   'marital_status': 'married_civ_spouse',
#   'occupation': 'craft_repair',
#   'relationship': 'husband',
#   'race': 'white',
#   'sex': 'male',
#   'native_country': 'united_states',
#   'age': 38,
#   'capital_gain': 0,
#   'capital_loss': 0,
#   'hours_per_week': 50},
#  {'workclass': 'private',
#   'education': '10th',
#   'marital_status': 'never_married',
#   'occupation': 'transport_moving',
#   'relationship': 'not_in_family',
#   'race': 'amer_indian_eskimo',
#   'sex': 'male',
#   'native_country': 'united_states',
#   'age': 22,
#   'capital_gain': 0,
#   'capital_loss': 0,
#   'hours_per_week': 84},
#  {'workclass': 'self_emp_inc',
#   'education': 'hs_grad',
#   'marital_status': 'married_civ_spouse',
#   'occupation': 'craft_repair',
#   'relationship': 'husband',
#   'race': 'white',
#   'sex': 'male',
#   'native_country': 'united_states',
#   'age': 64,
#   'capital_gain': 2635,
#   'capital_loss': 0,
#   'hours_per_week': 10},
#  {'workclass': 'private',
#   'education': 'assoc_acdm',
#   'marital_status': 'never_married',
#   'occupation': 'sales',
#   'relationship': 'own_child',
#   'race': 'white',
#   'sex': 'female',
#   'native_country': 'united_states',
#   'age': 22,
#   'capital_gain': 0,
#   'capital_loss': 0,
#   'hours_per_week': 25},
#  {'workclass': 'private',
#   'education': 'some_college',
#   'marital_status': 'never_married',
#   'occupation': 'sales',
#   'relationship': 'other_relative',
#   'race': 'white',
#   'sex': 'male',
#   'native_country': 'united_states',
#   'age': 29,
#   'capital_gain': 0,
#   'capital_loss': 0,
#   'hours_per_week': 50},
#  {'workclass': 'local_gov',
#   'education': 'hs_grad',
#   'marital_status': 'married_civ_spouse',
#   'occupation': 'protective_serv',
#   'relationship': 'husband',
#   'race': 'white',
#   'sex': 'male',
#   'native_country': 'united_states',
#   'age': 34,
#   'capital_gain': 0,
#   'capital_loss': 0,
#   'hours_per_week': 57},
#  {'workclass': 'private',
#   'education': 'some_college',
#   'marital_status': 'never_married',
#   'occupation': 'adm_clerical',
#   'relationship': 'own_child',
#   'race': 'white',
#   'sex': 'female',
#   'native_country': 'united_states',
#   'age': 20,
#   'capital_gain': 0,
#   'capital_loss': 0,
#   'hours_per_week': 10},
#  {'workclass': 'private',
#   'education': 'bachelors',
#   'marital_status': 'never_married',
#   'occupation': 'exec_managerial',
#   'relationship': 'not_in_family',
#   'race': 'white',
#   'sex': 'male',
#   'native_country': 'united_states',
#   'age': 34,
#   'capital_gain': 0,
#   'capital_loss': 1741,
#   'hours_per_week': 40},
#  {'workclass': 'private',
#   'education': 'hs_grad',
#   'marital_status': 'married_civ_spouse',
#   'occupation': 'craft_repair',
#   'relationship': 'husband',
#   'race': 'white',
#   'sex': 'male',
#   'native_country': 'united_states',
#   'age': 53,
#   'capital_gain': 0,
#   'capital_loss': 0,
#   'hours_per_week': 40},
#  {'workclass': 'private',
#   'education': 'bachelors',
#   'marital_status': 'never_married',
#   'occupation': 'exec_managerial',
#   'relationship': 'not_in_family',
#   'race': 'white',
#   'sex': 'male',
#   'native_country': 'united_states',
#   'age': 25,
#   'capital_gain': 0,
#   'capital_loss': 0,
#   'hours_per_week': 50},
#  {'workclass': 'private',
#   'education': 'hs_grad',
#   'marital_status': 'married_civ_spouse',
#   'occupation': 'exec_managerial',
#   'relationship': 'husband',
#   'race': 'white',
#   'sex': 'male',
#   'native_country': 'united_states',
#   'age': 57,
#   'capital_gain': 0,
#   'capital_loss': 0,
#   'hours_per_week': 60},
#  {'workclass': 'private',
#   'education': 'hs_grad',
#   'marital_status': 'never_married',
#   'occupation': 'handlers_cleaners',
#   'relationship': 'own_child',
#   'race': 'white',
#   'sex': 'male',
#   'native_country': 'united_states',
#   'age': 19,
#   'capital_gain': 0,
#   'capital_loss': 0,
#   'hours_per_week': 52},
#  {'workclass': 'private',
#   'education': 'some_college',
#   'marital_status': 'married_civ_spouse',
#   'occupation': 'transport_moving',
#   'relationship': 'husband',
#   'race': 'white',
#   'sex': 'male',
#   'native_country': 'united_states',
#   'age': 27,
#   'capital_gain': 0,
#   'capital_loss': 0,
#   'hours_per_week': 40},
#  {'workclass': 'private',
#   'education': 'some_college',
#   'marital_status': 'never_married',
#   'occupation': 'other_service',
#   'relationship': 'own_child',
#   'race': 'black',
#   'sex': 'male',
#   'native_country': 'united_states',
#   'age': 34,
#   'capital_gain': 0,
#   'capital_loss': 0,
#   'hours_per_week': 40},
#  {'workclass': 'private',
#   'education': 'hs_grad',
#   'marital_status': 'divorced',
#   'occupation': 'craft_repair',
#   'relationship': 'unmarried',
#   'race': 'white',
#   'sex': 'female',
#   'native_country': 'united_states',
#   'age': 52,
#   'capital_gain': 0,
#   'capital_loss': 0,
#   'hours_per_week': 50},
#  {'workclass': 'private',
#   'education': 'assoc_voc',
#   'marital_status': 'married_civ_spouse',
#   'occupation': 'other_service',
#   'relationship': 'husband',
#   'race': 'white',
#   'sex': 'male',
#   'native_country': 'united_states',
#   'age': 34,
#   'capital_gain': 0,
#   'capital_loss': 0,
#   'hours_per_week': 40},
#  {'workclass': 'self_emp_not_inc',
#   'education': 'some_college',
#   'marital_status': 'never_married',
#   'occupation': 'farming_fishing',
#   'relationship': 'own_child',
#   'race': 'white',
#   'sex': 'male',
#   'native_country': 'united_states',
#   'age': 23,
#   'capital_gain': 0,
#   'capital_loss': 0,
#   'hours_per_week': 35},
#  {'workclass': 'private',
#   'education': 'hs_grad',
#   'marital_status': 'married_civ_spouse',
#   'occupation': 'craft_repair',
#   'relationship': 'husband',
#   'race': 'white',
#   'sex': 'male',
#   'native_country': 'united_states',
#   'age': 42,
#   'capital_gain': 0,
#   'capital_loss': 0,
#   'hours_per_week': 50},
#  {'workclass': 'private',
#   'education': 'bachelors',
#   'marital_status': 'never_married',
#   'occupation': 'exec_managerial',
#   'relationship': 'not_in_family',
#   'race': 'black',
#   'sex': 'female',
#   'native_country': 'united_states',
#   'age': 31,
#   'capital_gain': 0,
#   'capital_loss': 0,
#   'hours_per_week': 40},
#  {'workclass': 'private',
#   'education': 'assoc_voc',
#   'marital_status': 'separated',
#   'occupation': 'prof_specialty',
#   'relationship': 'unmarried',
#   'race': 'white',
#   'sex': 'female',
#   'native_country': 'united_states',
#   'age': 37,
#   'capital_gain': 0,
#   'capital_loss': 0,
#   'hours_per_week': 32},
#  {'workclass': 'private',
#   'education': 'assoc_voc',
#   'marital_status': 'married_civ_spouse',
#   'occupation': 'craft_repair',
#   'relationship': 'husband',
#   'race': 'white',
#   'sex': 'male',
#   'native_country': 'united_states',
#   'age': 48,
#   'capital_gain': 0,
#   'capital_loss': 0,
#   'hours_per_week': 40},
#  {'workclass': 'state_gov',
#   'education': 'hs_grad',
#   'marital_status': 'separated',
#   'occupation': 'other_service',
#   'relationship': 'not_in_family',
#   'race': 'white',
#   'sex': 'female',
#   'native_country': 'united_states',
#   'age': 57,
#   'capital_gain': 0,
#   'capital_loss': 0,
#   'hours_per_week': 35},
#  {'workclass': 'self_emp_not_inc',
#   'education': 'bachelors',
#   'marital_status': 'married_civ_spouse',
#   'occupation': 'exec_managerial',
#   'relationship': 'husband',
#   'race': 'white',
#   'sex': 'male',
#   'native_country': 'united_states',
#   'age': 39,
#   'capital_gain': 0,
#   'capital_loss': 0,
#   'hours_per_week': 40},
#  {'workclass': 'private',
#   'education': 'hs_grad',
#   'marital_status': 'divorced',
#   'occupation': 'machine_op_inspct',
#   'relationship': 'not_in_family',
#   'race': 'black',
#   'sex': 'female',
#   'native_country': 'united_states',
#   'age': 39,
#   'capital_gain': 0,
#   'capital_loss': 0,
#   'hours_per_week': 70},
#  {'workclass': 'private',
#   'education': 'some_college',
#   'marital_status': 'divorced',
#   'occupation': 'sales',
#   'relationship': 'not_in_family',
#   'race': 'white',
#   'sex': 'male',
#   'native_country': 'united_states',
#   'age': 33,
#   'capital_gain': 0,
#   'capital_loss': 0,
#   'hours_per_week': 40},
#  {'workclass': 'private',
#   'education': '7th_8th',
#   'marital_status': 'married_civ_spouse',
#   'occupation': 'craft_repair',
#   'relationship': 'husband',
#   'race': 'white',
#   'sex': 'male',
#   'native_country': 'united_states',
#   'age': 50,
#   'capital_gain': 0,
#   'capital_loss': 0,
#   'hours_per_week': 40},
#  {'workclass': 'private',
#   'education': 'assoc_acdm',
#   'marital_status': 'married_civ_spouse',
#   'occupation': 'protective_serv',
#   'relationship': 'husband',
#   'race': 'white',
#   'sex': 'male',
#   'native_country': 'united_states',
#   'age': 52,
#   'capital_gain': 0,
#   'capital_loss': 0,
#   'hours_per_week': 40},
#  {'workclass': 'state_gov',
#   'education': 'bachelors',
#   'marital_status': 'never_married',
#   'occupation': 'prof_specialty',
#   'relationship': 'own_child',
#   'race': 'white',
#   'sex': 'male',
#   'native_country': 'united_states',
#   'age': 26,
#   'capital_gain': 0,
#   'capital_loss': 0,
#   'hours_per_week': 40},
#  {'workclass': 'private',
#   'education': 'some_college',
#   'marital_status': 'never_married',
#   'occupation': 'adm_clerical',
#   'relationship': 'own_child',
#   'race': 'white',
#   'sex': 'male',
#   'native_country': 'united_states',
#   'age': 23,
#   'capital_gain': 0,
#   'capital_loss': 0,
#   'hours_per_week': 40},
#  {'workclass': 'private',
#   'education': 'prof_school',
#   'marital_status': 'married_civ_spouse',
#   'occupation': 'sales',
#   'relationship': 'husband',
#   'race': 'white',
#   'sex': 'male',
#   'native_country': 'united_states',
#   'age': 32,
#   'capital_gain': 15024,
#   'capital_loss': 0,
#   'hours_per_week': 60},
#  {'workclass': 'private',
#   'education': 'hs_grad',
#   'marital_status': 'divorced',
#   'occupation': 'other_service',
#   'relationship': 'not_in_family',
#   'race': 'white',
#   'sex': 'female',
#   'native_country': 'united_states',
#   'age': 72,
#   'capital_gain': 0,
#   'capital_loss': 0,
#   'hours_per_week': 16},
#  {'workclass': 'private',
#   'education': 'hs_grad',
#   'marital_status': 'separated',
#   'occupation': 'exec_managerial',
#   'relationship': 'not_in_family',
#   'race': 'white',
#   'sex': 'female',
#   'native_country': 'united_states',
#   'age': 45,
#   'capital_gain': 0,
#   'capital_loss': 0,
#   'hours_per_week': 40},
#  {'workclass': 'private',
#   'education': '11th',
#   'marital_status': 'never_married',
#   'occupation': 'adm_clerical',
#   'relationship': 'own_child',
#   'race': 'white',
#   'sex': 'female',
#   'native_country': 'united_states',
#   'age': 17,
#   'capital_gain': 0,
#   'capital_loss': 0,
#   'hours_per_week': 20},
#  {'workclass': 'private',
#   'education': 'bachelors',
#   'marital_status': 'never_married',
#   'occupation': 'sales',
#   'relationship': 'not_in_family',
#   'race': 'white',
#   'sex': 'female',
#   'native_country': 'united_states',
#   'age': 35,
#   'capital_gain': 8614,
#   'capital_loss': 0,
#   'hours_per_week': 45},
#  {'workclass': 'private',
#   'education': 'hs_grad',
#   'marital_status': 'never_married',
#   'occupation': 'exec_managerial',
#   'relationship': 'own_child',
#   'race': 'white',
#   'sex': 'female',
#   'native_country': 'united_states',
#   'age': 63,
#   'capital_gain': 0,
#   'capital_loss': 0,
#   'hours_per_week': 40},
#  {'workclass': 'state_gov',
#   'education': 'hs_grad',
#   'marital_status': 'never_married',
#   'occupation': 'craft_repair',
#   'relationship': 'not_in_family',
#   'race': 'white',
#   'sex': 'male',
#   'native_country': 'united_states',
#   'age': 44,
#   'capital_gain': 0,
#   'capital_loss': 0,
#   'hours_per_week': 40},
#  {'workclass': 'state_gov',
#   'education': 'bachelors',
#   'marital_status': 'married_civ_spouse',
#   'occupation': 'tech_support',
#   'relationship': 'husband',
#   'race': 'white',
#   'sex': 'male',
#   'native_country': 'united_states',
#   'age': 30,
#   'capital_gain': 0,
#   'capital_loss': 0,
#   'hours_per_week': 40},
#  {'workclass': 'federal_gov',
#   'education': 'hs_grad',
#   'marital_status': 'divorced',
#   'occupation': 'adm_clerical',
#   'relationship': 'not_in_family',
#   'race': 'white',
#   'sex': 'male',
#   'native_country': 'united_states',
#   'age': 48,
#   'capital_gain': 0,
#   'capital_loss': 0,
#   'hours_per_week': 40},
#  {'workclass': 'private',
#   'education': 'hs_grad',
#   'marital_status': 'married_civ_spouse',
#   'occupation': 'prof_specialty',
#   'relationship': 'husband',
#   'race': 'white',
#   'sex': 'male',
#   'native_country': 'united_states',
#   'age': 52,
#   'capital_gain': 7688,
#   'capital_loss': 0,
#   'hours_per_week': 40},
#  {'workclass': 'self_emp_not_inc',
#   'education': 'some_college',
#   'marital_status': 'married_civ_spouse',
#   'occupation': 'sales',
#   'relationship': 'husband',
#   'race': 'white',
#   'sex': 'male',
#   'native_country': 'united_states',
#   'age': 46,
#   'capital_gain': 0,
#   'capital_loss': 0,
#   'hours_per_week': 60},
#  {'workclass': 'self_emp_not_inc',
#   'education': '11th',
#   'marital_status': 'never_married',
#   'occupation': 'farming_fishing',
#   'relationship': 'own_child',
#   'race': 'white',
#   'sex': 'male',
#   'native_country': 'united_states',
#   'age': 37,
#   'capital_gain': 0,
#   'capital_loss': 0,
#   'hours_per_week': 37},
#  {'workclass': 'private',
#   'education': 'hs_grad',
#   'marital_status': 'married_civ_spouse',
#   'occupation': 'exec_managerial',
#   'relationship': 'husband',
#   'race': 'white',
#   'sex': 'male',
#   'native_country': 'united_states',
#   'age': 43,
#   'capital_gain': 0,
#   'capital_loss': 0,
#   'hours_per_week': 45},
#  {'workclass': 'self_emp_inc',
#   'education': 'bachelors',
#   'marital_status': 'divorced',
#   'occupation': 'exec_managerial',
#   'relationship': 'not_in_family',
#   'race': 'white',
#   'sex': 'female',
#   'native_country': 'united_states',
#   'age': 46,
#   'capital_gain': 0,
#   'capital_loss': 0,
#   'hours_per_week': 50},
#  {'workclass': 'state_gov',
#   'education': 'hs_grad',
#   'marital_status': 'never_married',
#   'occupation': 'tech_support',
#   'relationship': 'own_child',
#   'race': 'white',
#   'sex': 'male',
#   'native_country': 'united_states',
#   'age': 35,
#   'capital_gain': 0,
#   'capital_loss': 0,
#   'hours_per_week': 40},
#  {'workclass': 'private',
#   'education': 'hs_grad',
#   'marital_status': 'married_civ_spouse',
#   'occupation': 'craft_repair',
#   'relationship': 'husband',
#   'race': 'white',
#   'sex': 'male',
#   'native_country': 'united_states',
#   'age': 63,
#   'capital_gain': 0,
#   'capital_loss': 0,
#   'hours_per_week': 40},
#  {'workclass': 'private',
#   'education': 'some_college',
#   'marital_status': 'never_married',
#   'occupation': 'prof_specialty',
#   'relationship': 'not_in_family',
#   'race': 'white',
#   'sex': 'female',
#   'native_country': 'united_states',
#   'age': 33,
#   'capital_gain': 3674,
#   'capital_loss': 0,
#   'hours_per_week': 16},
#  {'workclass': 'private',
#   'education': 'some_college',
#   'marital_status': 'divorced',
#   'occupation': 'adm_clerical',
#   'relationship': 'unmarried',
#   'race': 'white',
#   'sex': 'female',
#   'native_country': 'united_states',
#   'age': 46,
#   'capital_gain': 0,
#   'capital_loss': 0,
#   'hours_per_week': 40},
#  {'workclass': 'private',
#   'education': 'some_college',
#   'marital_status': 'married_spouse_absent',
#   'occupation': 'prof_specialty',
#   'relationship': 'not_in_family',
#   'race': 'white',
#   'sex': 'male',
#   'native_country': 'united_states',
#   'age': 33,
#   'capital_gain': 0,
#   'capital_loss': 0,
#   'hours_per_week': 40},
#  {'workclass': 'private',
#   'education': 'some_college',
#   'marital_status': 'divorced',
#   'occupation': 'craft_repair',
#   'relationship': 'not_in_family',
#   'race': 'white',
#   'sex': 'male',
#   'native_country': 'united_states',
#   'age': 55,
#   'capital_gain': 0,
#   'capital_loss': 0,
#   'hours_per_week': 40},
#  {'workclass': 'local_gov',
#   'education': 'masters',
#   'marital_status': 'married_civ_spouse',
#   'occupation': 'prof_specialty',
#   'relationship': 'husband',
#   'race': 'white',
#   'sex': 'male',
#   'native_country': 'united_states',
#   'age': 36,
#   'capital_gain': 0,
#   'capital_loss': 0,
#   'hours_per_week': 50},
#  {'workclass': 'private',
#   'education': 'hs_grad',
#   'marital_status': 'never_married',
#   'occupation': 'adm_clerical',
#   'relationship': 'own_child',
#   'race': 'white',
#   'sex': 'male',
#   'native_country': 'united_states',
#   'age': 24,
#   'capital_gain': 0,
#   'capital_loss': 0,
#   'hours_per_week': 40},
#  {'workclass': 'private',
#   'education': 'bachelors',
#   'marital_status': 'married_civ_spouse',
#   'occupation': 'exec_managerial',
#   'relationship': 'husband',
#   'race': 'white',
#   'sex': 'male',
#   'native_country': 'united_states',
#   'age': 48,
#   'capital_gain': 0,
#   'capital_loss': 0,
#   'hours_per_week': 55},
#  {'workclass': 'private',
#   'education': 'hs_grad',
#   'marital_status': 'never_married',
#   'occupation': 'adm_clerical',
#   'relationship': 'own_child',
#   'race': 'white',
#   'sex': 'female',
#   'native_country': 'united_states',
#   'age': 18,
#   'capital_gain': 0,
#   'capital_loss': 0,
#   'hours_per_week': 20},
#  {'workclass': 'private',
#   'education': 'hs_grad',
#   'marital_status': 'married_civ_spouse',
#   'occupation': 'machine_op_inspct',
#   'relationship': 'husband',
#   'race': 'white',
#   'sex': 'male',
#   'native_country': 'united_states',
#   'age': 27,
#   'capital_gain': 0,
#   'capital_loss': 0,
#   'hours_per_week': 40},
#  {'workclass': 'private',
#   'education': 'some_college',
#   'marital_status': 'married_civ_spouse',
#   'occupation': 'sales',
#   'relationship': 'husband',
#   'race': 'white',
#   'sex': 'male',
#   'native_country': 'united_states',
#   'age': 58,
#   'capital_gain': 0,
#   'capital_loss': 0,
#   'hours_per_week': 45},
#  {'workclass': 'private',
#   'education': 'hs_grad',
#   'marital_status': 'never_married',
#   'occupation': 'other_service',
#   'relationship': 'own_child',
#   'race': 'white',
#   'sex': 'male',
#   'native_country': 'united_states',
#   'age': 21,
#   'capital_gain': 0,
#   'capital_loss': 0,
#   'hours_per_week': 35},
#  {'workclass': 'self_emp_not_inc',
#   'education': 'hs_grad',
#   'marital_status': 'divorced',
#   'occupation': 'farming_fishing',
#   'relationship': 'unmarried',
#   'race': 'white',
#   'sex': 'male',
#   'native_country': 'united_states',
#   'age': 26,
#   'capital_gain': 0,
#   'capital_loss': 0,
#   'hours_per_week': 65},
#  {'workclass': 'local_gov',
#   'education': 'bachelors',
#   'marital_status': 'never_married',
#   'occupation': 'prof_specialty',
#   'relationship': 'not_in_family',
#   'race': 'white',
#   'sex': 'female',
#   'native_country': 'united_states',
#   'age': 23,
#   'capital_gain': 0,
#   'capital_loss': 0,
#   'hours_per_week': 35},
#  {'workclass': 'private',
#   'education': 'hs_grad',
#   'marital_status': 'married_civ_spouse',
#   'occupation': 'sales',
#   'relationship': 'husband',
#   'race': 'white',
#   'sex': 'male',
#   'native_country': 'united_states',
#   'age': 28,
#   'capital_gain': 0,
#   'capital_loss': 0,
#   'hours_per_week': 40},
#  {'workclass': 'self_emp_not_inc',
#   'education': 'assoc_acdm',
#   'marital_status': 'separated',
#   'occupation': 'sales',
#   'relationship': 'not_in_family',
#   'race': 'black',
#   'sex': 'male',
#   'native_country': 'united_states',
#   'age': 51,
#   'capital_gain': 0,
#   'capital_loss': 0,
#   'hours_per_week': 30},
#  {'workclass': 'private',
#   'education': 'masters',
#   'marital_status': 'married_civ_spouse',
#   'occupation': 'exec_managerial',
#   'relationship': 'husband',
#   'race': 'white',
#   'sex': 'male',
#   'native_country': 'united_states',
#   'age': 46,
#   'capital_gain': 0,
#   'capital_loss': 0,
#   'hours_per_week': 55},
#  {'workclass': 'private',
#   'education': 'bachelors',
#   'marital_status': 'married_civ_spouse',
#   'occupation': 'sales',
#   'relationship': 'wife',
#   'race': 'white',
#   'sex': 'female',
#   'native_country': 'united_states',
#   'age': 52,
#   'capital_gain': 15024,
#   'capital_loss': 0,
#   'hours_per_week': 60},
#  {'workclass': 'local_gov',
#   'education': 'bachelors',
#   'marital_status': 'divorced',
#   'occupation': 'prof_specialty',
#   'relationship': 'not_in_family',
#   'race': 'black',
#   'sex': 'female',
#   'native_country': 'united_states',
#   'age': 47,
#   'capital_gain': 0,
#   'capital_loss': 0,
#   'hours_per_week': 40},
#  {'workclass': 'private',
#   'education': 'some_college',
#   'marital_status': 'married_civ_spouse',
#   'occupation': 'sales',
#   'relationship': 'wife',
#   'race': 'white',
#   'sex': 'female',
#   'native_country': 'united_states',
#   'age': 23,
#   'capital_gain': 0,
#   'capital_loss': 0,
#   'hours_per_week': 47},
#  {'workclass': 'private',
#   'education': 'some_college',
#   'marital_status': 'married_civ_spouse',
#   'occupation': 'sales',
#   'relationship': 'husband',
#   'race': 'white',
#   'sex': 'male',
#   'native_country': 'united_states',
#   'age': 27,
#   'capital_gain': 0,
#   'capital_loss': 0,
#   'hours_per_week': 50},
#  {'workclass': 'private',
#   'education': 'hs_grad',
#   'marital_status': 'never_married',
#   'occupation': 'other_service',
#   'relationship': 'own_child',
#   'race': 'black',
#   'sex': 'male',
#   'native_country': 'united_states',
#   'age': 24,
#   'capital_gain': 0,
#   'capital_loss': 1721,
#   'hours_per_week': 30},
#  {'workclass': 'private',
#   'education': 'hs_grad',
#   'marital_status': 'married_civ_spouse',
#   'occupation': 'transport_moving',
#   'relationship': 'husband',
#   'race': 'white',
#   'sex': 'male',
#   'native_country': 'dominican_republic',
#   'age': 43,
#   'capital_gain': 0,
#   'capital_loss': 0,
#   'hours_per_week': 30},
#  {'workclass': 'private',
#   'education': 'some_college',
#   'marital_status': 'never_married',
#   'occupation': 'adm_clerical',
#   'relationship': 'own_child',
#   'race': 'white',
#   'sex': 'male',
#   'native_country': 'united_states',
#   'age': 23,
#   'capital_gain': 0,
#   'capital_loss': 0,
#   'hours_per_week': 40},
#  {'workclass': 'private',
#   'education': '5th_6th',
#   'marital_status': 'separated',
#   'occupation': 'machine_op_inspct',
#   'relationship': 'not_in_family',
#   'race': 'white',
#   'sex': 'male',
#   'native_country': 'united_states',
#   'age': 56,
#   'capital_gain': 0,
#   'capital_loss': 0,
#   'hours_per_week': 40},
#  {'workclass': 'private',
#   'education': 'some_college',
#   'marital_status': 'divorced',
#   'occupation': 'exec_managerial',
#   'relationship': 'unmarried',
#   'race': 'white',
#   'sex': 'female',
#   'native_country': 'united_states',
#   'age': 45,
#   'capital_gain': 0,
#   'capital_loss': 0,
#   'hours_per_week': 40},
#  {'workclass': 'private',
#   'education': 'hs_grad',
#   'marital_status': 'married_civ_spouse',
#   'occupation': 'tech_support',
#   'relationship': 'husband',
#   'race': 'white',
#   'sex': 'male',
#   'native_country': 'united_states',
#   'age': 50,
#   'capital_gain': 0,
#   'capital_loss': 0,
#   'hours_per_week': 40},
#  {'workclass': 'private',
#   'education': 'hs_grad',
#   'marital_status': 'never_married',
#   'occupation': 'sales',
#   'relationship': 'unmarried',
#   'race': 'white',
#   'sex': 'male',
#   'native_country': 'united_states',
#   'age': 24,
#   'capital_gain': 0,
#   'capital_loss': 0,
#   'hours_per_week': 45},
#  {'workclass': 'private',
#   'education': 'hs_grad',
#   'marital_status': 'divorced',
#   'occupation': 'prof_specialty',
#   'relationship': 'own_child',
#   'race': 'white',
#   'sex': 'female',
#   'native_country': 'united_states',
#   'age': 30,
#   'capital_gain': 0,
#   'capital_loss': 0,
#   'hours_per_week': 40},
#  {'workclass': 'private',
#   'education': 'hs_grad',
#   'marital_status': 'never_married',
#   'occupation': 'other_service',
#   'relationship': 'own_child',
#   'race': 'white',
#   'sex': 'female',
#   'native_country': 'united_states',
#   'age': 18,
#   'capital_gain': 0,
#   'capital_loss': 0,
#   'hours_per_week': 30},
#  {'workclass': 'private',
#   'education': 'hs_grad',
#   'marital_status': 'divorced',
#   'occupation': 'machine_op_inspct',
#   'relationship': 'not_in_family',
#   'race': 'white',
#   'sex': 'male',
#   'native_country': 'united_states',
#   'age': 58,
#   'capital_gain': 3325,
#   'capital_loss': 0,
#   'hours_per_week': 30},
#  {'workclass': 'private',
#   'education': '7th_8th',
#   'marital_status': 'married_civ_spouse',
#   'occupation': 'transport_moving',
#   'relationship': 'husband',
#   'race': 'white',
#   'sex': 'male',
#   'native_country': 'united_states',
#   'age': 23,
#   'capital_gain': 0,
#   'capital_loss': 0,
#   'hours_per_week': 32},
#  {'workclass': 'state_gov',
#   'education': 'bachelors',
#   'marital_status': 'never_married',
#   'occupation': 'prof_specialty',
#   'relationship': 'own_child',
#   'race': 'white',
#   'sex': 'female',
#   'native_country': 'united_states',
#   'age': 32,
#   'capital_gain': 0,
#   'capital_loss': 0,
#   'hours_per_week': 40},
#  {'workclass': 'private',
#   'education': 'some_college',
#   'marital_status': 'never_married',
#   'occupation': 'machine_op_inspct',
#   'relationship': 'own_child',
#   'race': 'black',
#   'sex': 'female',
#   'native_country': 'jamaica',
#   'age': 23,
#   'capital_gain': 0,
#   'capital_loss': 0,
#   'hours_per_week': 20},
#  {'workclass': 'private',
#   'education': 'some_college',
#   'marital_status': 'married_civ_spouse',
#   'occupation': 'other_service',
#   'relationship': 'wife',
#   'race': 'white',
#   'sex': 'female',
#   'native_country': 'united_states',
#   'age': 30,
#   'capital_gain': 0,
#   'capital_loss': 0,
#   'hours_per_week': 45},
#  {'workclass': 'private',
#   'education': 'some_college',
#   'marital_status': 'married_civ_spouse',
#   'occupation': 'transport_moving',
#   'relationship': 'husband',
#   'race': 'white',
#   'sex': 'male',
#   'native_country': 'united_states',
#   'age': 43,
#   'capital_gain': 0,
#   'capital_loss': 0,
#   'hours_per_week': 50},
#  {'workclass': 'self_emp_inc',
#   'education': 'hs_grad',
#   'marital_status': 'married_civ_spouse',
#   'occupation': 'exec_managerial',
#   'relationship': 'husband',
#   'race': 'white',
#   'sex': 'male',
#   'native_country': 'united_states',
#   'age': 26,
#   'capital_gain': 0,
#   'capital_loss': 0,
#   'hours_per_week': 60},
#  {'workclass': 'private',
#   'education': 'hs_grad',
#   'marital_status': 'never_married',
#   'occupation': 'adm_clerical',
#   'relationship': 'own_child',
#   'race': 'white',
#   'sex': 'female',
#   'native_country': 'united_states',
#   'age': 37,
#   'capital_gain': 0,
#   'capital_loss': 0,
#   'hours_per_week': 37},
#  {'workclass': 'private',
#   'education': 'some_college',
#   'marital_status': 'married_civ_spouse',
#   'occupation': 'exec_managerial',
#   'relationship': 'husband',
#   'race': 'white',
#   'sex': 'male',
#   'native_country': 'united_states',
#   'age': 57,
#   'capital_gain': 0,
#   'capital_loss': 0,
#   'hours_per_week': 50},
#  {'workclass': 'private',
#   'education': 'bachelors',
#   'marital_status': 'never_married',
#   'occupation': 'other_service',
#   'relationship': 'not_in_family',
#   'race': 'white',
#   'sex': 'male',
#   'native_country': 'united_states',
#   'age': 26,
#   'capital_gain': 0,
#   'capital_loss': 0,
#   'hours_per_week': 30},
#  {'workclass': 'self_emp_not_inc',
#   'education': '7th_8th',
#   'marital_status': 'married_civ_spouse',
#   'occupation': 'craft_repair',
#   'relationship': 'husband',
#   'race': 'white',
#   'sex': 'male',
#   'native_country': 'united_states',
#   'age': 41,
#   'capital_gain': 0,
#   'capital_loss': 2179,
#   'hours_per_week': 40},
#  {'workclass': 'private',
#   'education': '7th_8th',
#   'marital_status': 'married_civ_spouse',
#   'occupation': 'prof_specialty',
#   'relationship': 'husband',
#   'race': 'white',
#   'sex': 'male',
#   'native_country': 'united_states',
#   'age': 62,
#   'capital_gain': 0,
#   'capital_loss': 0,
#   'hours_per_week': 20},
#  {'workclass': 'private',
#   'education': 'some_college',
#   'marital_status': 'married_civ_spouse',
#   'occupation': 'sales',
#   'relationship': 'husband',
#   'race': 'white',
#   'sex': 'male',
#   'native_country': 'united_states',
#   'age': 44,
#   'capital_gain': 0,
#   'capital_loss': 0,
#   'hours_per_week': 60},
#  {'workclass': 'private',
#   'education': 'masters',
#   'marital_status': 'married_civ_spouse',
#   'occupation': 'exec_managerial',
#   'relationship': 'husband',
#   'race': 'white',
#   'sex': 'male',
#   'native_country': 'united_states',
#   'age': 53,
#   'capital_gain': 0,
#   'capital_loss': 0,
#   'hours_per_week': 40},
#  {'workclass': 'state_gov',
#   'education': 'bachelors',
#   'marital_status': 'married_civ_spouse',
#   'occupation': 'prof_specialty',
#   'relationship': 'wife',
#   'race': 'white',
#   'sex': 'female',
#   'native_country': 'united_states',
#   'age': 41,
#   'capital_gain': 0,
#   'capital_loss': 0,
#   'hours_per_week': 40},
#  {'workclass': 'self_emp_inc',
#   'education': 'bachelors',
#   'marital_status': 'married_civ_spouse',
#   'occupation': 'exec_managerial',
#   'relationship': 'husband',
#   'race': 'white',
#   'sex': 'male',
#   'native_country': 'united_states',
#   'age': 66,
#   'capital_gain': 10605,
#   'capital_loss': 0,
#   'hours_per_week': 40},
#  {'workclass': 'private',
#   'education': 'bachelors',
#   'marital_status': 'married_civ_spouse',
#   'occupation': 'exec_managerial',
#   'relationship': 'husband',
#   'race': 'asian_pac_islander',
#   'sex': 'male',
#   'native_country': 'united_states',
#   'age': 44,
#   'capital_gain': 0,
#   'capital_loss': 0,
#   'hours_per_week': 40},
#  {'workclass': 'private',
#   'education': 'hs_grad',
#   'marital_status': 'married_civ_spouse',
#   'occupation': 'machine_op_inspct',
#   'relationship': 'husband',
#   'race': 'white',
#   'sex': 'male',
#   'native_country': 'united_states',
#   'age': 39,
#   'capital_gain': 0,
#   'capital_loss': 0,
#   'hours_per_week': 50},
#  {'workclass': 'private',
#   'education': 'some_college',
#   'marital_status': 'divorced',
#   'occupation': 'prof_specialty',
#   'relationship': 'not_in_family',
#   'race': 'white',
#   'sex': 'male',
#   'native_country': 'united_states',
#   'age': 33,
#   'capital_gain': 0,
#   'capital_loss': 0,
#   'hours_per_week': 40},
#  {'workclass': 'local_gov',
#   'education': '7th_8th',
#   'marital_status': 'married_civ_spouse',
#   'occupation': 'craft_repair',
#   'relationship': 'husband',
#   'race': 'white',
#   'sex': 'male',
#   'native_country': 'united_states',
#   'age': 58,
#   'capital_gain': 0,
#   'capital_loss': 0,
#   'hours_per_week': 40},
#  {'workclass': 'private',
#   'education': '10th',
#   'marital_status': 'married_civ_spouse',
#   'occupation': 'craft_repair',
#   'relationship': 'husband',
#   'race': 'white',
#   'sex': 'male',
#   'native_country': 'united_states',
#   'age': 55,
#   'capital_gain': 0,
#   'capital_loss': 0,
#   'hours_per_week': 40},
#  {'workclass': 'private',
#   'education': '9th',
#   'marital_status': 'married_civ_spouse',
#   'occupation': 'handlers_cleaners',
#   'relationship': 'husband',
#   'race': 'black',
#   'sex': 'male',
#   'native_country': 'united_states',
#   'age': 58,
#   'capital_gain': 0,
#   'capital_loss': 0,
#   'hours_per_week': 60},
#  {'workclass': 'self_emp_not_inc',
#   'education': 'hs_grad',
#   'marital_status': 'married_civ_spouse',
#   'occupation': 'sales',
#   'relationship': 'husband',
#   'race': 'white',
#   'sex': 'male',
#   'native_country': 'united_states',
#   'age': 33,
#   'capital_gain': 0,
#   'capital_loss': 0,
#   'hours_per_week': 60},
#  {'workclass': 'self_emp_inc',
#   'education': 'hs_grad',
#   'marital_status': 'married_civ_spouse',
#   'occupation': 'sales',
#   'relationship': 'husband',
#   'race': 'white',
#   'sex': 'male',
#   'native_country': 'united_states',
#   'age': 65,
#   'capital_gain': 0,
#   'capital_loss': 0,
#   'hours_per_week': 50},
#  {'workclass': 'private',
#   'education': '10th',
#   'marital_status': 'never_married',
#   'occupation': 'craft_repair',
#   'relationship': 'not_in_family',
#   'race': 'white',
#   'sex': 'male',
#   'native_country': 'united_states',
#   'age': 29,
#   'capital_gain': 0,
#   'capital_loss': 0,
#   'hours_per_week': 48},
#  {'workclass': 'private',
#   'education': 'assoc_acdm',
#   'marital_status': 'married_civ_spouse',
#   'occupation': 'sales',
#   'relationship': 'husband',
#   'race': 'white',
#   'sex': 'male',
#   'native_country': 'united_states',
#   'age': 41,
#   'capital_gain': 0,
#   'capital_loss': 0,
#   'hours_per_week': 20},
#  {'workclass': 'private',
#   'education': 'hs_grad',
#   'marital_status': 'married_civ_spouse',
#   'occupation': 'transport_moving',
#   'relationship': 'husband',
#   'race': 'white',
#   'sex': 'male',
#   'native_country': 'united_states',
#   'age': 33,
#   'capital_gain': 3908,
#   'capital_loss': 0,
#   'hours_per_week': 40},
#  {'workclass': 'private',
#   'education': 'hs_grad',
#   'marital_status': 'married_civ_spouse',
#   'occupation': 'transport_moving',
#   'relationship': 'husband',
#   'race': 'white',
#   'sex': 'male',
#   'native_country': 'united_states',
#   'age': 52,
#   'capital_gain': 0,
#   'capital_loss': 0,
#   'hours_per_week': 60},
#  {'workclass': 'private',
#   'education': 'assoc_voc',
#   'marital_status': 'divorced',
#   'occupation': 'adm_clerical',
#   'relationship': 'not_in_family',
#   'race': 'white',
#   'sex': 'female',
#   'native_country': 'united_states',
#   'age': 23,
#   'capital_gain': 0,
#   'capital_loss': 0,
#   'hours_per_week': 30},
#  {'workclass': 'private',
#   'education': 'hs_grad',
#   'marital_status': 'widowed',
#   'occupation': 'craft_repair',
#   'relationship': 'not_in_family',
# ...
#   'native_country': 'united_states',
#   'age': 55,
#   'capital_gain': 0,
#   'capital_loss': 0,
#   'hours_per_week': 60},
#  {'workclass': 'private',
#   'education': 'hs_grad',
#   'marital_status': 'never_married',
#   'occupation': 'tech_support',
#   'relationship': 'other_relative',
#   'race': 'white',
#   'sex': 'male',
#   'native_country': 'united_states',
#   'age': 47,
#   'capital_gain': 0,
#   'capital_loss': 0,
#   'hours_per_week': 50},
#  {'workclass': 'private',
#   'education': '11th',
#   'marital_status': 'married_civ_spouse',
#   'occupation': 'prof_specialty',
#   'relationship': 'husband',
#   'race': 'black',
#   'sex': 'male',
#   'native_country': 'united_states',
#   'age': 69,
#   'capital_gain': 0,
#   'capital_loss': 0,
#   'hours_per_week': 45},
#  {'workclass': 'state_gov',
#   'education': 'masters',
#   'marital_status': 'married_civ_spouse',
#   'occupation': 'prof_specialty',
#   'relationship': 'husband',
#   'race': 'white',
#   'sex': 'male',
#   'native_country': 'united_states',
#   'age': 65,
#   'capital_gain': 6514,
#   'capital_loss': 0,
#   'hours_per_week': 35},
#  {'workclass': 'private',
#   'education': 'assoc_voc',
#   'marital_status': 'married_civ_spouse',
#   'occupation': 'craft_repair',
#   'relationship': 'husband',
#   'race': 'white',
#   'sex': 'male',
#   'native_country': 'united_states',
#   'age': 23,
#   'capital_gain': 0,
#   'capital_loss': 0,
#   'hours_per_week': 55},
#  {'workclass': 'private',
#   'education': '7th_8th',
#   'marital_status': 'divorced',
#   'occupation': 'machine_op_inspct',
#   'relationship': 'unmarried',
#   'race': 'white',
#   'sex': 'female',
#   'native_country': 'united_states',
#   'age': 61,
#   'capital_gain': 0,
#   'capital_loss': 0,
#   'hours_per_week': 40},
#  {'workclass': 'private',
#   'education': 'hs_grad',
#   'marital_status': 'married_civ_spouse',
#   'occupation': 'craft_repair',
#   'relationship': 'husband',
#   'race': 'white',
#   'sex': 'male',
#   'native_country': 'united_states',
#   'age': 42,
#   'capital_gain': 0,
#   'capital_loss': 0,
#   'hours_per_week': 55},
#  {'workclass': 'private',
#   'education': '11th',
#   'marital_status': 'never_married',
#   'occupation': 'farming_fishing',
#   'relationship': 'unmarried',
#   'race': 'white',
#   'sex': 'male',
#   'native_country': 'united_states',
#   'age': 21,
#   'capital_gain': 0,
#   'capital_loss': 0,
#   'hours_per_week': 40},
#  {'workclass': 'private',
#   'education': 'hs_grad',
#   'marital_status': 'married_civ_spouse',
#   'occupation': 'adm_clerical',
#   'relationship': 'wife',
#   'race': 'white',
#   'sex': 'female',
#   'native_country': 'united_states',
#   'age': 49,
#   'capital_gain': 0,
#   'capital_loss': 0,
#   'hours_per_week': 30},
#  {'workclass': 'private',
#   'education': 'assoc_voc',
#   'marital_status': 'divorced',
#   'occupation': 'exec_managerial',
#   'relationship': 'not_in_family',
#   'race': 'white',
#   'sex': 'female',
#   'native_country': 'united_states',
#   'age': 45,
#   'capital_gain': 0,
#   'capital_loss': 0,
#   'hours_per_week': 44},
#  {'workclass': 'private',
#   'education': 'bachelors',
#   'marital_status': 'married_civ_spouse',
#   'occupation': 'sales',
#   'relationship': 'husband',
#   'race': 'white',
#   'sex': 'male',
#   'native_country': 'united_states',
#   'age': 30,
#   'capital_gain': 7298,
#   'capital_loss': 0,
#   'hours_per_week': 50},
#  {'workclass': 'private',
#   'education': 'some_college',
#   'marital_status': 'divorced',
#   'occupation': 'sales',
#   'relationship': 'unmarried',
#   'race': 'white',
#   'sex': 'female',
#   'native_country': 'peru',
#   'age': 27,
#   'capital_gain': 0,
#   'capital_loss': 0,
#   'hours_per_week': 40},
#  {'workclass': 'private',
#   'education': 'bachelors',
#   'marital_status': 'never_married',
#   'occupation': 'tech_support',
#   'relationship': 'not_in_family',
#   'race': 'black',
#   'sex': 'male',
#   'native_country': 'jamaica',
#   'age': 28,
#   'capital_gain': 0,
#   'capital_loss': 0,
#   'hours_per_week': 30},
#  {'workclass': 'private',
#   'education': 'bachelors',
#   'marital_status': 'married_civ_spouse',
#   'occupation': 'adm_clerical',
#   'relationship': 'husband',
#   'race': 'asian_pac_islander',
#   'sex': 'male',
#   'native_country': 'philippines',
#   'age': 41,
#   'capital_gain': 3103,
#   'capital_loss': 0,
#   'hours_per_week': 35},
#  {'workclass': 'private',
#   'education': 'hs_grad',
#   'marital_status': 'never_married',
#   'occupation': 'handlers_cleaners',
#   'relationship': 'own_child',
#   'race': 'white',
#   'sex': 'male',
#   'native_country': 'united_states',
#   'age': 56,
#   'capital_gain': 0,
#   'capital_loss': 0,
#   'hours_per_week': 28},
#  {'workclass': 'private',
#   'education': 'some_college',
#   'marital_status': 'married_civ_spouse',
#   'occupation': 'adm_clerical',
#   'relationship': 'husband',
#   'race': 'white',
#   'sex': 'male',
#   'native_country': 'united_states',
#   'age': 46,
#   'capital_gain': 0,
#   'capital_loss': 0,
#   'hours_per_week': 40},
#  {'workclass': 'private',
#   'education': 'hs_grad',
#   'marital_status': 'married_civ_spouse',
#   'occupation': 'craft_repair',
#   'relationship': 'husband',
#   'race': 'white',
#   'sex': 'male',
#   'native_country': 'united_states',
#   'age': 38,
#   'capital_gain': 0,
#   'capital_loss': 0,
#   'hours_per_week': 40},
#  {'workclass': 'private',
#   'education': 'assoc_acdm',
#   'marital_status': 'never_married',
#   'occupation': 'craft_repair',
#   'relationship': 'not_in_family',
#   'race': 'white',
#   'sex': 'male',
#   'native_country': 'united_states',
#   'age': 36,
#   'capital_gain': 0,
#   'capital_loss': 0,
#   'hours_per_week': 40},
#  {'workclass': 'private',
#   'education': 'some_college',
#   'marital_status': 'married_civ_spouse',
#   'occupation': 'machine_op_inspct',
#   'relationship': 'husband',
#   'race': 'asian_pac_islander',
#   'sex': 'male',
#   'native_country': 'united_states',
#   'age': 36,
#   'capital_gain': 0,
#   'capital_loss': 0,
#   'hours_per_week': 50},
#  {'workclass': 'private',
#   'education': '10th',
#   'marital_status': 'divorced',
#   'occupation': 'prof_specialty',
#   'relationship': 'unmarried',
#   'race': 'white',
#   'sex': 'female',
#   'native_country': 'united_states',
#   'age': 62,
#   'capital_gain': 0,
#   'capital_loss': 0,
#   'hours_per_week': 40},
#  {'workclass': 'local_gov',
#   'education': 'bachelors',
#   'marital_status': 'never_married',
#   'occupation': 'protective_serv',
#   'relationship': 'not_in_family',
#   'race': 'white',
#   'sex': 'male',
#   'native_country': 'united_states',
#   'age': 26,
#   'capital_gain': 0,
#   'capital_loss': 0,
#   'hours_per_week': 40},
#  {'workclass': 'private',
#   'education': 'assoc_voc',
#   'marital_status': 'divorced',
#   'occupation': 'other_service',
#   'relationship': 'not_in_family',
#   'race': 'white',
#   'sex': 'male',
#   'native_country': 'united_states',
#   'age': 52,
#   'capital_gain': 0,
#   'capital_loss': 0,
#   'hours_per_week': 32},
#  {'workclass': 'private',
#   'education': 'some_college',
#   'marital_status': 'married_civ_spouse',
#   'occupation': 'prof_specialty',
#   'relationship': 'wife',
#   'race': 'white',
#   'sex': 'female',
#   'native_country': 'united_states',
#   'age': 63,
#   'capital_gain': 0,
#   'capital_loss': 0,
#   'hours_per_week': 12},
#  {'workclass': 'private',
#   'education': 'some_college',
#   'marital_status': 'divorced',
#   'occupation': 'adm_clerical',
#   'relationship': 'not_in_family',
#   'race': 'white',
#   'sex': 'female',
#   'native_country': 'united_states',
#   'age': 43,
#   'capital_gain': 0,
#   'capital_loss': 0,
#   'hours_per_week': 44},
#  {'workclass': 'private',
#   'education': 'hs_grad',
#   'marital_status': 'never_married',
#   'occupation': 'adm_clerical',
#   'relationship': 'not_in_family',
#   'race': 'white',
#   'sex': 'female',
#   'native_country': 'united_states',
#   'age': 39,
#   'capital_gain': 0,
#   'capital_loss': 0,
#   'hours_per_week': 40},
#  {'workclass': 'private',
#   'education': 'some_college',
#   'marital_status': 'never_married',
#   'occupation': 'adm_clerical',
#   'relationship': 'not_in_family',
#   'race': 'white',
#   'sex': 'male',
#   'native_country': 'united_states',
#   'age': 20,
#   'capital_gain': 0,
#   'capital_loss': 0,
#   'hours_per_week': 25},
#  {'workclass': 'private',
#   'education': 'hs_grad',
#   'marital_status': 'never_married',
#   'occupation': 'handlers_cleaners',
#   'relationship': 'not_in_family',
#   'race': 'white',
#   'sex': 'female',
#   'native_country': 'united_states',
#   'age': 21,
#   'capital_gain': 0,
#   'capital_loss': 0,
#   'hours_per_week': 40},
#  {'workclass': 'private',
#   'education': 'bachelors',
#   'marital_status': 'married_civ_spouse',
#   'occupation': 'craft_repair',
#   'relationship': 'husband',
#   'race': 'white',
#   'sex': 'male',
#   'native_country': 'canada',
#   'age': 29,
#   'capital_gain': 0,
#   'capital_loss': 0,
#   'hours_per_week': 40},
#  {'workclass': 'private',
#   'education': 'hs_grad',
#   'marital_status': 'never_married',
#   'occupation': 'craft_repair',
#   'relationship': 'own_child',
#   'race': 'asian_pac_islander',
#   'sex': 'male',
#   'native_country': 'united_states',
#   'age': 33,
#   'capital_gain': 0,
#   'capital_loss': 0,
#   'hours_per_week': 40},
#  {'workclass': 'private',
#   'education': '10th',
#   'marital_status': 'separated',
#   'occupation': 'other_service',
#   'relationship': 'own_child',
#   'race': 'white',
#   'sex': 'female',
#   'native_country': 'united_states',
#   'age': 25,
#   'capital_gain': 0,
#   'capital_loss': 0,
#   'hours_per_week': 25},
#  {'workclass': 'private',
#   'education': 'some_college',
#   'marital_status': 'never_married',
#   'occupation': 'adm_clerical',
#   'relationship': 'own_child',
#   'race': 'white',
#   'sex': 'male',
#   'native_country': 'united_states',
#   'age': 22,
#   'capital_gain': 0,
#   'capital_loss': 0,
#   'hours_per_week': 40},
#  {'workclass': 'private',
#   'education': 'hs_grad',
#   'marital_status': 'never_married',
#   'occupation': 'adm_clerical',
#   'relationship': 'other_relative',
#   'race': 'black',
#   'sex': 'male',
#   'native_country': 'jamaica',
#   'age': 24,
#   'capital_gain': 0,
#   'capital_loss': 0,
#   'hours_per_week': 40},
#  {'workclass': 'private',
#   'education': 'assoc_acdm',
#   'marital_status': 'divorced',
#   'occupation': 'exec_managerial',
#   'relationship': 'not_in_family',
#   'race': 'white',
#   'sex': 'female',
#   'native_country': 'united_states',
#   'age': 37,
#   'capital_gain': 0,
#   'capital_loss': 0,
#   'hours_per_week': 48},
#  {'workclass': 'private',
#   'education': '9th',
#   'marital_status': 'never_married',
#   'occupation': 'other_service',
#   'relationship': 'own_child',
#   'race': 'black',
#   'sex': 'male',
#   'native_country': 'united_states',
#   'age': 18,
#   'capital_gain': 0,
#   'capital_loss': 0,
#   'hours_per_week': 15},
#  {'workclass': 'local_gov',
#   'education': 'masters',
#   'marital_status': 'divorced',
#   'occupation': 'exec_managerial',
#   'relationship': 'not_in_family',
#   'race': 'white',
#   'sex': 'female',
#   'native_country': 'united_states',
#   'age': 37,
#   'capital_gain': 0,
#   'capital_loss': 0,
#   'hours_per_week': 40},
#  {'workclass': 'private',
#   'education': 'bachelors',
#   'marital_status': 'married_civ_spouse',
#   'occupation': 'exec_managerial',
#   'relationship': 'husband',
#   'race': 'white',
#   'sex': 'male',
#   'native_country': 'united_states',
#   'age': 37,
#   'capital_gain': 0,
#   'capital_loss': 0,
#   'hours_per_week': 60},
#  {'workclass': 'self_emp_not_inc',
#   'education': 'some_college',
#   'marital_status': 'never_married',
#   'occupation': 'prof_specialty',
#   'relationship': 'not_in_family',
#   'race': 'asian_pac_islander',
#   'sex': 'male',
#   'native_country': 'united_states',
#   'age': 24,
#   'capital_gain': 0,
#   'capital_loss': 0,
#   'hours_per_week': 30},
#  {'workclass': 'self_emp_not_inc',
#   'education': 'hs_grad',
#   'marital_status': 'married_civ_spouse',
#   'occupation': 'other_service',
#   'relationship': 'husband',
#   'race': 'white',
#   'sex': 'male',
#   'native_country': 'united_states',
#   'age': 58,
#   'capital_gain': 7688,
#   'capital_loss': 0,
#   'hours_per_week': 55},
#  {'workclass': 'private',
#   'education': 'hs_grad',
#   'marital_status': 'divorced',
#   'occupation': 'adm_clerical',
#   'relationship': 'not_in_family',
#   'race': 'white',
#   'sex': 'female',
#   'native_country': 'united_states',
#   'age': 48,
#   'capital_gain': 0,
#   'capital_loss': 0,
#   'hours_per_week': 37},
#  {'workclass': 'private',
#   'education': 'some_college',
#   'marital_status': 'never_married',
#   'occupation': 'tech_support',
#   'relationship': 'not_in_family',
#   'race': 'black',
#   'sex': 'male',
#   'native_country': 'philippines',
#   'age': 33,
#   'capital_gain': 0,
#   'capital_loss': 0,
#   'hours_per_week': 40},
#  {'workclass': 'private',
#   'education': 'some_college',
#   'marital_status': 'never_married',
#   'occupation': 'sales',
#   'relationship': 'not_in_family',
#   'race': 'white',
#   'sex': 'female',
#   'native_country': 'united_states',
#   'age': 20,
#   'capital_gain': 0,
#   'capital_loss': 0,
#   'hours_per_week': 30},
#  {'workclass': 'private',
#   'education': 'hs_grad',
#   'marital_status': 'married_civ_spouse',
#   'occupation': 'exec_managerial',
#   'relationship': 'husband',
#   'race': 'white',
#   'sex': 'male',
#   'native_country': 'united_states',
#   'age': 37,
#   'capital_gain': 0,
#   'capital_loss': 0,
#   'hours_per_week': 40},
#  {'workclass': 'private',
#   'education': 'masters',
#   'marital_status': 'married_civ_spouse',
#   'occupation': 'exec_managerial',
#   'relationship': 'husband',
#   'race': 'white',
#   'sex': 'male',
#   'native_country': 'united_states',
#   'age': 53,
#   'capital_gain': 0,
#   'capital_loss': 0,
#   'hours_per_week': 45},
#  {'workclass': 'private',
#   'education': 'hs_grad',
#   'marital_status': 'never_married',
#   'occupation': 'adm_clerical',
#   'relationship': 'unmarried',
#   'race': 'white',
#   'sex': 'female',
#   'native_country': 'united_states',
#   'age': 23,
#   'capital_gain': 0,
#   'capital_loss': 0,
#   'hours_per_week': 40},
#  {'workclass': 'private',
#   'education': 'some_college',
#   'marital_status': 'married_civ_spouse',
#   'occupation': 'exec_managerial',
#   'relationship': 'husband',
#   'race': 'white',
#   'sex': 'male',
#   'native_country': 'united_states',
#   'age': 41,
#   'capital_gain': 0,
#   'capital_loss': 1887,
#   'hours_per_week': 50},
#  {'workclass': 'self_emp_inc',
#   'education': 'bachelors',
#   'marital_status': 'married_civ_spouse',
#   'occupation': 'exec_managerial',
#   'relationship': 'husband',
#   'race': 'white',
#   'sex': 'male',
#   'native_country': 'united_states',
#   'age': 55,
#   'capital_gain': 0,
#   'capital_loss': 2415,
#   'hours_per_week': 50},
#  {'workclass': 'self_emp_not_inc',
#   'education': 'masters',
#   'marital_status': 'married_civ_spouse',
#   'occupation': 'exec_managerial',
#   'relationship': 'husband',
#   'race': 'white',
#   'sex': 'male',
#   'native_country': 'united_states',
#   'age': 40,
#   'capital_gain': 99999,
#   'capital_loss': 0,
#   'hours_per_week': 50},
#  {'workclass': 'private',
#   'education': 'hs_grad',
#   'marital_status': 'divorced',
#   'occupation': 'craft_repair',
#   'relationship': 'not_in_family',
#   'race': 'white',
#   'sex': 'male',
#   'native_country': 'united_states',
#   'age': 48,
#   'capital_gain': 0,
#   'capital_loss': 0,
#   'hours_per_week': 40},
#  {'workclass': 'private',
#   'education': '1st_4th',
#   'marital_status': 'married_civ_spouse',
#   'occupation': 'machine_op_inspct',
#   'relationship': 'husband',
#   'race': 'white',
#   'sex': 'male',
#   'native_country': 'mexico',
#   'age': 31,
#   'capital_gain': 0,
#   'capital_loss': 0,
#   'hours_per_week': 40},
#  {'workclass': 'private',
#   'education': 'some_college',
#   'marital_status': 'married_civ_spouse',
#   'occupation': 'craft_repair',
#   'relationship': 'husband',
#   'race': 'white',
#   'sex': 'male',
#   'native_country': 'united_states',
#   'age': 37,
#   'capital_gain': 0,
#   'capital_loss': 0,
#   'hours_per_week': 40},
#  {'workclass': 'private',
#   'education': 'doctorate',
#   'marital_status': 'never_married',
#   'occupation': 'exec_managerial',
#   'relationship': 'not_in_family',
#   'race': 'white',
#   'sex': 'male',
#   'native_country': 'united_states',
#   'age': 52,
#   'capital_gain': 0,
#   'capital_loss': 0,
#   'hours_per_week': 40},
#  {'workclass': 'federal_gov',
#   'education': 'bachelors',
#   'marital_status': 'never_married',
#   'occupation': 'adm_clerical',
#   'relationship': 'not_in_family',
#   'race': 'white',
#   'sex': 'male',
#   'native_country': 'united_states',
#   'age': 45,
#   'capital_gain': 0,
#   'capital_loss': 0,
#   'hours_per_week': 55},
#  ...]

# %%
dv = DictVectorizer(sparse=False)

# %%
dv.fit(train_dicts)
# Out:
# DictVectorizer(sparse=False)

# %%
dv.get_feature_names_out()
# Out:
# array(['age', 'capital_gain', 'capital_loss', 'education=10th',
#        'education=11th', 'education=12th', 'education=1st_4th',
#        'education=5th_6th', 'education=7th_8th', 'education=9th',
#        'education=assoc_acdm', 'education=assoc_voc',
#        'education=bachelors', 'education=doctorate', 'education=hs_grad',
#        'education=masters', 'education=preschool',
#        'education=prof_school', 'education=some_college',
#        'hours_per_week', 'marital_status=divorced',
#        'marital_status=married_af_spouse',
#        'marital_status=married_civ_spouse',
#        'marital_status=married_spouse_absent',
#        'marital_status=never_married', 'marital_status=separated',
#        'marital_status=widowed', 'native_country=cambodia',
#        'native_country=canada', 'native_country=china',
#        'native_country=columbia', 'native_country=cuba',
#        'native_country=dominican_republic', 'native_country=ecuador',
#        'native_country=el_salvador', 'native_country=england',
#        'native_country=france', 'native_country=germany',
#        'native_country=greece', 'native_country=guatemala',
#        'native_country=haiti', 'native_country=holand_netherlands',
#        'native_country=honduras', 'native_country=hong',
#        'native_country=hungary', 'native_country=india',
#        'native_country=iran', 'native_country=ireland',
#        'native_country=italy', 'native_country=jamaica',
#        'native_country=japan', 'native_country=laos',
#        'native_country=mexico', 'native_country=nicaragua',
#        'native_country=outlying_us(guam_usvi_etc)', 'native_country=peru',
#        'native_country=philippines', 'native_country=poland',
#        'native_country=portugal', 'native_country=puerto_rico',
#        'native_country=scotland', 'native_country=south',
#        'native_country=taiwan', 'native_country=thailand',
#        'native_country=trinadad&tobago', 'native_country=united_states',
#        'native_country=vietnam', 'native_country=yugoslavia',
#        'occupation=adm_clerical', 'occupation=armed_forces',
#        'occupation=craft_repair', 'occupation=exec_managerial',
#        'occupation=farming_fishing', 'occupation=handlers_cleaners',
#        'occupation=machine_op_inspct', 'occupation=other_service',
#        'occupation=priv_house_serv', 'occupation=prof_specialty',
#        'occupation=protective_serv', 'occupation=sales',
#        'occupation=tech_support', 'occupation=transport_moving',
#        'race=amer_indian_eskimo', 'race=asian_pac_islander', 'race=black',
#        'race=other', 'race=white', 'relationship=husband',
#        'relationship=not_in_family', 'relationship=other_relative',
#        'relationship=own_child', 'relationship=unmarried',
#        'relationship=wife', 'sex=female', 'sex=male',
#        'workclass=federal_gov', 'workclass=local_gov',
#        'workclass=private', 'workclass=self_emp_inc',
#        'workclass=self_emp_not_inc', 'workclass=state_gov',
#        'workclass=without_pay'], dtype=object)

# %%
X_train = dv.transform(train_dicts)

# %%
val_dicts = df_val[categorical + numerical].to_dict(orient='records')

# %%
X_val = dv.transform(val_dicts)

# %%
from sklearn.linear_model import LogisticRegression

# %%
model = LogisticRegression()
model.fit(X_train, y_train)
# Out:
# /home/singh/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
model.intercept_[0]
# Out:
# -1.3223487064017911

# %%
model.coef_[0].round(3)
# Out:
# array([ 7.000e-03,  0.000e+00,  1.000e-03, -3.840e-01, -4.700e-01,
#        -1.350e-01, -1.190e-01, -2.320e-01, -4.250e-01, -2.690e-01,
#        -7.300e-02, -9.400e-02,  6.070e-01,  3.370e-01, -7.390e-01,
#         6.410e-01, -3.600e-02,  3.860e-01, -3.150e-01,  1.400e-02,
#        -4.380e-01,  1.400e-02,  1.027e+00, -9.400e-02, -1.490e+00,
#        -2.140e-01, -1.250e-01,  1.000e-03,  2.000e-03, -3.500e-02,
#        -4.000e-02, -9.000e-03, -4.200e-02, -1.600e-02, -5.600e-02,
#         2.000e-03,  1.000e-02,  1.000e-02, -2.100e-02, -3.100e-02,
#        -1.600e-02, -1.000e-03, -4.000e-03, -4.000e-03, -1.000e-03,
#        -3.700e-02, -4.000e-03, -1.000e-03, -7.000e-03, -2.900e-02,
#        -1.100e-02, -1.000e-02, -4.140e-01, -2.200e-02, -7.000e-03,
#        -1.400e-02, -1.900e-02, -8.000e-03, -2.400e-02, -5.800e-02,
#        -3.000e-03, -4.200e-02,  2.000e-03, -5.000e-03, -9.000e-03,
#        -3.070e-01, -4.000e-02, -1.000e-03, -2.630e-01, -5.000e-03,
#        -3.440e-01,  9.270e-01, -5.940e-01, -4.870e-01, -4.850e-01,
#        -9.250e-01, -5.500e-02,  7.680e-01,  3.100e-02,  2.000e-01,
#         1.900e-01, -2.770e-01, -1.460e-01, -2.090e-01, -5.300e-01,
#        -1.250e-01, -3.090e-01,  3.510e-01, -4.360e-01, -2.820e-01,
#        -1.114e+00, -6.210e-01,  7.820e-01, -8.260e-01, -4.930e-01,
#         1.520e-01, -3.350e-01, -1.900e-01,  1.400e-01, -8.080e-01,
#        -2.660e-01, -1.300e-02])

# %%
model.predict(X_val)
# Out:
# array([1, 0, 0, ..., 0, 0, 0])

# %%
model.predict_proba(X_val)
# Out:
# array([[0.31535831, 0.68464169],
#        [0.97463707, 0.02536293],
#        [0.99809419, 0.00190581],
#        ...,
#        [0.9300655 , 0.0699345 ],
#        [0.99547275, 0.00452725],
#        [0.61941297, 0.38058703]])

# %%
y_pred = model.predict_proba(X_val)[:, 1]

# %%
y_pred >= 0.5
# Out:
# array([ True, False, False, ..., False, False, False])

# %%
(y_pred >= 0.5).astype(int)
# Out:
# array([1, 0, 0, ..., 0, 0, 0])

# %%
df_val[y_pred >= 0.5]
# Out:
#       age         workclass     education  education_num      marital_status  \
# 0      55           private     doctorate             16  married_civ_spouse
# 3      71      self_emp_inc       masters             14  married_civ_spouse
# 8      34  self_emp_not_inc     bachelors             13  married_civ_spouse
# 10     64       federal_gov     doctorate             16  married_civ_spouse
# 11     36           private  some_college             10  married_civ_spouse
# ...   ...               ...           ...            ...                 ...
# 5996   43           private     bachelors             13  married_civ_spouse
# 5999   39           private     bachelors             13  married_civ_spouse
# 6012   45      self_emp_inc       hs_grad              9  married_civ_spouse
# 6027   49           private       masters             14  married_civ_spouse
# 6029   42         local_gov     bachelors             13  married_civ_spouse
#
#            occupation relationship                race     sex  capital_gain  \
# 0      prof_specialty      husband               white    male             0
# 3     exec_managerial      husband               white    male         99999
# 8      prof_specialty      husband               black    male             0
# 10     prof_specialty      husband  asian_pac_islander    male             0
# 11    exec_managerial      husband               white    male             0
# ...               ...          ...                 ...     ...           ...
# 5996  exec_managerial      husband               white    male          7298
# 5999  exec_managerial      husband               white    male             0
# 6012  exec_managerial      husband               white    male             0
# 6027   prof_specialty      husband               white    male             0
# 6029   prof_specialty         wife               white  female             0
#
#       capital_loss  hours_per_week native_country
# 0                0              40  united_states
# 3                0              40  united_states
# 8             1887              48  united_states
# 10               0              40          china
# 11               0              50  united_states
# ...            ...             ...            ...
# 5996             0              40  united_states
# 5999             0              45  united_states
# 6012             0              48  united_states
# 6027             0              50  united_states
# 6029             0              50  united_states
#
# [1258 rows x 13 columns]

# %%
#accuracy
(y_val == (y_pred >= 0.5).astype(int)).mean()
# Out:
# 0.8446875517984419

# %%
list(zip(dv.get_feature_names_out(), model.coef_[0].round(3)))
# Out:
# [('age', 0.007),
#  ('capital_gain', 0.0),
#  ('capital_loss', 0.001),
#  ('education=10th', -0.384),
#  ('education=11th', -0.47),
#  ('education=12th', -0.135),
#  ('education=1st_4th', -0.119),
#  ('education=5th_6th', -0.232),
#  ('education=7th_8th', -0.425),
#  ('education=9th', -0.269),
#  ('education=assoc_acdm', -0.073),
#  ('education=assoc_voc', -0.094),
#  ('education=bachelors', 0.607),
#  ('education=doctorate', 0.337),
#  ('education=hs_grad', -0.739),
#  ('education=masters', 0.641),
#  ('education=preschool', -0.036),
#  ('education=prof_school', 0.386),
#  ('education=some_college', -0.315),
#  ('hours_per_week', 0.014),
#  ('marital_status=divorced', -0.438),
#  ('marital_status=married_af_spouse', 0.014),
#  ('marital_status=married_civ_spouse', 1.027),
#  ('marital_status=married_spouse_absent', -0.094),
#  ('marital_status=never_married', -1.49),
#  ('marital_status=separated', -0.214),
#  ('marital_status=widowed', -0.125),
#  ('native_country=cambodia', 0.001),
#  ('native_country=canada', 0.002),
#  ('native_country=china', -0.035),
#  ('native_country=columbia', -0.04),
#  ('native_country=cuba', -0.009),
#  ('native_country=dominican_republic', -0.042),
#  ('native_country=ecuador', -0.016),
#  ('native_country=el_salvador', -0.056),
#  ('native_country=england', 0.002),
#  ('native_country=france', 0.01),
#  ('native_country=germany', 0.01),
#  ('native_country=greece', -0.021),
#  ('native_country=guatemala', -0.031),
#  ('native_country=haiti', -0.016),
#  ('native_country=holand_netherlands', -0.001),
#  ('native_country=honduras', -0.004),
#  ('native_country=hong', -0.004),
#  ('native_country=hungary', -0.001),
#  ('native_country=india', -0.037),
#  ('native_country=iran', -0.004),
#  ('native_country=ireland', -0.001),
#  ('native_country=italy', -0.007),
#  ('native_country=jamaica', -0.029),
#  ('native_country=japan', -0.011),
#  ('native_country=laos', -0.01),
#  ('native_country=mexico', -0.414),
#  ('native_country=nicaragua', -0.022),
#  ('native_country=outlying_us(guam_usvi_etc)', -0.007),
#  ('native_country=peru', -0.014),
#  ('native_country=philippines', -0.019),
#  ('native_country=poland', -0.008),
#  ('native_country=portugal', -0.024),
#  ('native_country=puerto_rico', -0.058),
#  ('native_country=scotland', -0.003),
#  ('native_country=south', -0.042),
#  ('native_country=taiwan', 0.002),
#  ('native_country=thailand', -0.005),
#  ('native_country=trinadad&tobago', -0.009),
#  ('native_country=united_states', -0.307),
#  ('native_country=vietnam', -0.04),
#  ('native_country=yugoslavia', -0.001),
#  ('occupation=adm_clerical', -0.263),
#  ('occupation=armed_forces', -0.005),
#  ('occupation=craft_repair', -0.344),
#  ('occupation=exec_managerial', 0.927),
#  ('occupation=farming_fishing', -0.594),
#  ('occupation=handlers_cleaners', -0.487),
#  ('occupation=machine_op_inspct', -0.485),
#  ('occupation=other_service', -0.925),
#  ('occupation=priv_house_serv', -0.055),
#  ('occupation=prof_specialty', 0.768),
#  ('occupation=protective_serv', 0.031),
#  ('occupation=sales', 0.2),
#  ('occupation=tech_support', 0.19),
#  ('occupation=transport_moving', -0.277),
#  ('race=amer_indian_eskimo', -0.146),
#  ('race=asian_pac_islander', -0.209),
#  ('race=black', -0.53),
#  ('race=other', -0.125),
#  ('race=white', -0.309),
#  ('relationship=husband', 0.351),
#  ('relationship=not_in_family', -0.436),
#  ('relationship=other_relative', -0.282),
#  ('relationship=own_child', -1.114),
#  ('relationship=unmarried', -0.621),
#  ('relationship=wife', 0.782),
#  ('sex=female', -0.826),
#  ('sex=male', -0.493),
#  ('workclass=federal_gov', 0.152),
#  ('workclass=local_gov', -0.335),
#  ('workclass=private', -0.19),
#  ('workclass=self_emp_inc', 0.14),
#  ('workclass=self_emp_not_inc', -0.808),
#  ('workclass=state_gov', -0.266),
#  ('workclass=without_pay', -0.013)]

# %%
def tpr_fpr_dataframe(y_test, y_pred):
    scores = []

    thresholds = np.linspace(0, 1, 101)

    for t in thresholds:
        actual_positive = (y_test == 1)
        actual_negative = (y_test == 0)

        predict_positive = (y_pred >= t)
        predict_negative = (y_pred < t)
        
        tp = (predict_positive & actual_positive).sum()
        tn = (predict_negative & actual_negative).sum()

        fp = (predict_positive & actual_negative).sum()
        fn = (predict_negative & actual_positive).sum()

        scores.append((t, tp, fp, fn, tn))

    columns = ['threshold', 'tp', 'fp', 'fn', 'tn']
    df_scores = pd.DataFrame(scores, columns=columns)\
    
    df_scores['tpr'] = df_scores.tp / (df_scores.tp + df_scores.fn)
    df_scores['fpr'] = df_scores.fp / (df_scores.fp + df_scores.tn)

    return df_scores

# %%
df_scores = tpr_fpr_dataframe(y_val, y_pred)
df_scores[::10]
# Out:
#      threshold    tp    fp    fn    tn       tpr       fpr
# 0          0.0  1509  4524     0     0  1.000000  1.000000
# 10         0.1  1417  1714    92  2810  0.939032  0.378868
# 20         0.2  1260  1093   249  3431  0.834990  0.241600
# 30         0.3  1095   639   414  3885  0.725646  0.141247
# 40         0.4  1002   465   507  4059  0.664016  0.102785
# 50         0.5   915   343   594  4181  0.606362  0.075818
# 60         0.6   773   224   736  4300  0.512260  0.049514
# 70         0.7   645   132   864  4392  0.427435  0.029178
# 80         0.8   419    49  1090  4475  0.277667  0.010831
# 90         0.9   298    17  1211  4507  0.197482  0.003758
# 100        1.0    33     0  1476  4524  0.021869  0.000000

# %%
plt.plot(df_scores.threshold, df_scores['tpr'], label='TPR')
plt.plot(df_scores.threshold, df_scores['fpr'], label='FPR')
plt.legend()

# %%
plt.figure(figsize=(6,6))
plt.plot(df_scores.fpr, df_scores.tpr, label='model')

plt.xlabel('FPR')
plt.ylabel('TPR')
plt.legend()

# %%
from sklearn.metrics import roc_curve, auc

# %%
fpr, tpr, thresholds = roc_curve(y_val, y_pred)

# %%
plt.figure(figsize=(6,6))

plt.plot(fpr, tpr, label='model')
plt.plot([0,1], [0,1], label='random', linestyle='--')
# plt.plot(df_ideal.fpr, df_ideal.tpr, label='ideal')

plt.xlabel('FPR')
plt.ylabel('TPR')
plt.legend()

# %%
auc(fpr, tpr)
# Out:
# 0.8929631758520495

# %% [markdown]
# ### Trying a smaller model

# %%
small = ['education', 'sex', 'workclass', 'race']

# %%
dicts_train_small = df_train[small].to_dict(orient='records')
dicts_val_small = df_val[small].to_dict(orient='records')

# %%
dv_small = DictVectorizer(sparse=False)
dv_small.fit(dicts_train_small)
# Out:
# DictVectorizer(sparse=False)

# %%
dv_small.get_feature_names_out()
# Out:
# array(['education=10th', 'education=11th', 'education=12th',
#        'education=1st_4th', 'education=5th_6th', 'education=7th_8th',
#        'education=9th', 'education=assoc_acdm', 'education=assoc_voc',
#        'education=bachelors', 'education=doctorate', 'education=hs_grad',
#        'education=masters', 'education=preschool',
#        'education=prof_school', 'education=some_college',
#        'race=amer_indian_eskimo', 'race=asian_pac_islander', 'race=black',
#        'race=other', 'race=white', 'sex=female', 'sex=male',
#        'workclass=federal_gov', 'workclass=local_gov',
#        'workclass=private', 'workclass=self_emp_inc',
#        'workclass=self_emp_not_inc', 'workclass=state_gov',
#        'workclass=without_pay'], dtype=object)

# %%
X_train_small = dv_small.transform(dicts_train_small)
X_val_small = dv_small.transform(dicts_val_small)

# %%
model_small = LogisticRegression()
model_small.fit(X_train_small, y_train)
# Out:
# /home/singh/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
model_small.intercept_[0]
# Out:
# -2.2263234960392255

# %%
model_small.coef_[0]
# Out:
# array([-0.96614507, -1.31693192, -0.67739197, -1.47791454, -1.48221137,
#        -1.18034379, -1.19950249,  0.52498282,  0.5837813 ,  1.26543414,
#         2.72379779, -0.06851729,  1.89950697, -1.56989793,  2.50153556,
#         0.26590157, -0.30383028,  0.15798091, -0.02071926, -0.49121529,
#         0.48386769, -0.74609706,  0.57218082,  0.55980407,  0.04601111,
#        -0.09620932,  0.92448342, -0.11135073, -0.37581163, -1.12084316])

# %%
y_pred_small = model_small.predict_proba(X_val_small)[:,1]
y_pred_small >= 0.5
# Out:
# array([ True, False, False, ..., False, False, False])

# %%
tpr_fpr_dataframe(y_val, (y_pred_small >= 0.5).astype(int))
# Out:
#      threshold    tp    fp    fn    tn       tpr       fpr
# 0         0.00  1509  4524     0     0  1.000000  1.000000
# 1         0.01   386   194  1123  4330  0.255799  0.042882
# 2         0.02   386   194  1123  4330  0.255799  0.042882
# 3         0.03   386   194  1123  4330  0.255799  0.042882
# 4         0.04   386   194  1123  4330  0.255799  0.042882
# ..         ...   ...   ...   ...   ...       ...       ...
# 96        0.96   386   194  1123  4330  0.255799  0.042882
# 97        0.97   386   194  1123  4330  0.255799  0.042882
# 98        0.98   386   194  1123  4330  0.255799  0.042882
# 99        0.99   386   194  1123  4330  0.255799  0.042882
# 100       1.00   386   194  1123  4330  0.255799  0.042882
#
# [101 rows x 7 columns]

# %%
fpr, tpr, thresholds = roc_curve(y_val, (y_pred_small >= 0.5).astype(int))

# %%
auc(fpr, tpr)
# Out:
# 0.6064580685647388

# %% [markdown]
# ### Using the model

# %%
dicts_full_train = df_full_train[numerical + categorical].to_dict(orient='records')

# %%
dv = DictVectorizer(sparse=False)

# %%
X_full_train = dv.fit_transform(dicts_full_train)

# %%
y_full_train = df_full_train['income>50k'].values

# %%
model = LogisticRegression()
model.fit(X_full_train, y_full_train)
# Out:
# /home/singh/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
dicts_test = df_test[categorical + numerical].to_dict(orient='records')

# %%
X_test = dv.transform(dicts_test)

# %%
y_pred = model.predict_proba(X_test)[:, 1]

# %%
high_income_decision = (y_pred >= 0.5)

# %%
(y_test == high_income_decision).mean().sum()
# Out:
# 0.8357901726427622

# %%
thresholds = np.linspace(0, 1, 21)

scores = []

for t in thresholds:
    high_income_decision = (y_pred >= t)
    score = (y_test == high_income_decision).mean()
    print('%.2f %.3f' % (t, score))
    scores.append(score)
# Out:
# 0.00 0.246
# 0.05 0.564
# 0.10 0.655
# 0.15 0.709
# 0.20 0.745
# 0.25 0.776
# 0.30 0.805
# 0.35 0.822
# 0.40 0.831
# 0.45 0.835
# 0.50 0.836
# 0.55 0.834
# 0.60 0.832
# 0.65 0.825
# 0.70 0.816
# 0.75 0.811
# 0.80 0.802
# 0.85 0.797
# 0.90 0.789
# 0.95 0.780
# 1.00 0.754

# %%
scores
# Out:
# [0.2456839309428951,
#  0.5644090305444888,
#  0.6545152722443559,
#  0.7088977423638778,
#  0.7445551128818061,
#  0.7758964143426295,
#  0.8049800796812749,
#  0.8222443559096946,
#  0.8312084993359894,
#  0.8352589641434263,
#  0.8357901726427622,
#  0.8341965471447543,
#  0.8318725099601594,
#  0.8252324037184595,
#  0.8161354581673307,
#  0.8110889774236387,
#  0.802324037184595,
#  0.7965471447543161,
#  0.7890438247011953,
#  0.7802788844621514,
#  0.7543160690571049]

# %%
plt.plot(thresholds, scores)

# %%
actual_positive = (y_test == 1)
actual_negative = (y_test == 0)

# %%
t = 0.5
predict_positive = (y_pred >= t)
predict_negative = (y_pred < t)

# %%
tp = (predict_positive & actual_positive).sum()
tn = (predict_negative & actual_negative).sum()

# %%
fp = (predict_positive & actual_negative).sum()
fn = (predict_negative & actual_positive).sum()

# %%
 confusion_matrix = np.array([
    [tn, fp],
    [fn, tp]
 ])

# %%
confusion_matrix
# Out:
# array([[10531,   829],
#        [ 1644,  2056]])

# %%
(confusion_matrix / confusion_matrix.sum()).round(2)
# Out:
# array([[0.7 , 0.06],
#        [0.11, 0.14]])

# %%
# Accuracy

(tp + tn) / (tp + tn + fp + fn)
# Out:
# 0.8357901726427622

# %%
# precision
# Fraction of correct positive predictions 0/1 - 1 is positive

p = tp / (tp + fp)
p
# Out:
# 0.7126516464471404

# %%
# Recall
# Fraction of correct positive examples (or fraction of examples we predicted correctly)

r = tp / (tp + fn) # because fn are actually positive examples just predicted negative
r
# Out:
# 0.5556756756756757

# %% [markdown]
# ### ROC Curves

# %%
tpr = tp / (tp + fn)
tpr
# Out:
# 0.5556756756756757

# %%
fpr = fp / (fp + tn)
fpr
# Out:
# 0.07297535211267606

# %%
scores = []

thresholds = np.linspace(0, 1, 101)

for t in thresholds:
    actual_positive = (y_test == 1)
    actual_negative = (y_test == 0)

    predict_positive = (y_pred >= t)
    predict_negative = (y_pred < t)
    
    tp = (predict_positive & actual_positive).sum()
    tn = (predict_negative & actual_negative).sum()

    fp = (predict_positive & actual_negative).sum()
    fn = (predict_negative & actual_positive).sum()

    scores.append((t, tp, fp, fn, tn))

# %%
columns = ['threshold', 'tp', 'fp', 'fn', 'tn']
df_scores = pd.DataFrame(scores, columns=columns)

# %%
df_scores[::10]
# Out:
#      threshold    tp     fp    fn     tn
# 0          0.0  3700  11360     0      0
# 10         0.1  3557   5060   143   6300
# 20         0.2  3156   3303   544   8057
# 30         0.3  2762   1999   938   9361
# 40         0.4  2436   1278  1264  10082
# 50         0.5  2056    829  1644  10531
# 60         0.6  1709    541  1991  10819
# 70         0.7  1212    281  2488  11079
# 80         0.8   806     83  2894  11277
# 90         0.9   541     18  3159  11342
# 100        1.0     0      0  3700  11360

# %%
df_scores['tpr'] = df_scores.tp / (df_scores.tp + df_scores.fn)
df_scores['fpr'] = df_scores.fp / (df_scores.fp + df_scores.tn)

# %%
df_scores[::10]
# Out:
#      threshold    tp     fp    fn     tn       tpr       fpr
# 0          0.0  3700  11360     0      0  1.000000  1.000000
# 10         0.1  3557   5060   143   6300  0.961351  0.445423
# 20         0.2  3156   3303   544   8057  0.852973  0.290757
# 30         0.3  2762   1999   938   9361  0.746486  0.175968
# 40         0.4  2436   1278  1264  10082  0.658378  0.112500
# 50         0.5  2056    829  1644  10531  0.555676  0.072975
# 60         0.6  1709    541  1991  10819  0.461892  0.047623
# 70         0.7  1212    281  2488  11079  0.327568  0.024736
# 80         0.8   806     83  2894  11277  0.217838  0.007306
# 90         0.9   541     18  3159  11342  0.146216  0.001585
# 100        1.0     0      0  3700  11360  0.000000  0.000000

# %%
plt.plot(df_scores.threshold, df_scores['tpr'], label='TPR')
plt.plot(df_scores.threshold, df_scores['fpr'], label='FPR')
plt.legend()

# %%
plt.figure(figsize=(6,6))

plt.plot(df_scores.fpr, df_scores.tpr, label='model')
# plt.plot(df_random.fpr, df_random.tpr, label='random')
# plt.plot(df_ideal.fpr, df_ideal.tpr, label='ideal')

plt.xlabel('FPR')
plt.ylabel('TPR')
plt.legend()

# %%
from sklearn.metrics import roc_curve

# %%
fpr, tpr, thresholds = roc_curve(y_test, y_pred)

# %%
plt.figure(figsize=(6,6))

plt.plot(fpr, tpr, label='model')
# plt.plot(df_random.fpr, df_random.tpr, label='random')
# plt.plot(df_ideal.fpr, df_ideal.tpr, label='ideal')

plt.xlabel('FPR')
plt.ylabel('TPR')
plt.legend()

# %%
from sklearn.metrics import auc

# %%
auc(fpr, tpr)
# Out:
# 0.8795216144842026

# %%
from sklearn.metrics import roc_auc_score, auc, roc_curve
roc_auc_score(y_test, y_pred)
# Out:
# 0.8795216144842026

# %% [markdown]
# ### Cross Validation

# %%
def train(df_train, y_train, C=1.0):
    dicts = df_train[categorical + numerical].to_dict(orient='records')

    dv = DictVectorizer(sparse=False)
    X_train = dv.fit_transform(dicts)

    model = LogisticRegression(C=C, max_iter=1000)
    model.fit(X_train, y_train)

    return dv, model

# %%
dv, model = train(df_train, y_train, C=0.001)

# %%
def predict(df, dv, model):
    dicts = df[categorical + numerical].to_dict(orient='records')

    X=dv.transform(dicts)
    y_pred = model.predict_proba(X)[:, 1]

    return y_pred

# %%
y_pred = predict(df_val, dv, model)

# %%
from sklearn.model_selection import KFold

# %%
Kfold = KFold(n_splits=10, shuffle=True, random_state=1)

# %%
Kfold.split(df_full_train)
# Out:
# <generator object _BaseKFold.split at 0x7fd97816c040>

# %%
from tqdm.auto import tqdm

# %%
n_splits = 3

for C in tqdm([0.001, 0.01, 0.1, 0.5, 1, 5, 10 ]):
    scores = []

    for train_idx, test_idx in Kfold.split(df_full_train):
        df_train = df_full_train.iloc[train_idx]
        df_val = df_full_train.iloc[test_idx]

        y_train = df_train['income>50k'].values
        y_val = df_val['income>50k'].values

        dv, model = train(df_train, y_train, C=C)
        y_pred = predict(df_val, dv, model)

        auc = roc_auc_score(y_val, y_pred)
        scores.append(auc)
    
    print('C=%s %.3f +- %.3f' % (C, np.mean(scores), np.std(scores)))
# Out:
#   0%|          | 0/7 [00:00<?, ?it/s]
# C=0.001 0.881 +- 0.003
# /home/singh/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/singh/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/singh/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/singh/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/singh/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/singh/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/singh/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/singh/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/singh/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C=0.01 0.899 +- 0.005
# /home/singh/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/singh/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/singh/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/singh/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C=0.1 0.903 +- 0.005
# /home/singh/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/singh/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/singh/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/singh/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/singh/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/singh/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/singh/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/singh/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C=0.5 0.903 +- 0.005
# /home/singh/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/singh/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/singh/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/singh/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/singh/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/singh/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/singh/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/singh/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C=1 0.903 +- 0.005
# /home/singh/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/singh/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/singh/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/singh/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/singh/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/singh/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/singh/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/singh/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C=5 0.903 +- 0.005
# /home/singh/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/singh/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/singh/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/singh/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/singh/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/singh/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/singh/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C=10 0.903 +- 0.005
# /home/singh/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
dv, model = train(df_full_train, df_full_train['income>50k'].values, C=1.0)
y_pred = predict(df_test, dv, model)

auc = roc_auc_score(y_test, y_pred)
auc
# Out:
# /home/singh/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# 0.9015467857822611

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
for d in [1, 2, 3, 4, 5, 7, 10, 11, 20, None]:
    dt = DecisionTreeClassifier(max_depth=d)

    dt.fit(X_train, y_train)

    y_pred = dt.predict_proba(X_val)[:, 1]

    auc = roc_auc_score(y_val, y_pred)
    print('%4s -> %.3f' % (d, auc))
# Out:
#    1 -> 0.756
#    2 -> 0.805
#    3 -> 0.833
#    4 -> 0.852
#    5 -> 0.865
#    7 -> 0.887
#   10 -> 0.896
#   11 -> 0.891
#   20 -> 0.828
# None -> 0.778

# %%
scores = []

for d in [7, 10, 11]:
    for  s in [1, 2, 10, 15, 50, 100]:
        dt = DecisionTreeClassifier(max_depth=d, min_samples_leaf=s)

        dt.fit(X_train, y_train)

        y_pred = dt.predict_proba(X_val)[:, 1]

        auc = roc_auc_score(y_val, y_pred)
        scores.append((d, s, auc))

        # print('(%4s, %3s) -> %.3f' % (d, s, auc))

# %%
columns = ['max_depth', 'min_samples_leaf', 'auc']
df_scores = pd.DataFrame(scores, columns=columns)
df_scores.head()
# Out:
#    max_depth  min_samples_leaf       auc
# 0          7                 1  0.886539
# 1          7                 2  0.886709
# 2          7                10  0.891695
# 3          7                15  0.891265
# 4          7                50  0.892617

# %%
df_scores.sort_values(by='auc', ascending=False)
# Out:
#     max_depth  min_samples_leaf       auc
# 16         11                50  0.900152
# 17         11               100  0.899190
# 9          10                15  0.899113
# 8          10                10  0.898673
# 15         11                15  0.898211
# 11         10               100  0.897959
# 10         10                50  0.897820
# 7          10                 2  0.897531
# 14         11                10  0.896304
# 6          10                 1  0.895744
# 4           7                50  0.892617
# 13         11                 2  0.892358
# 5           7               100  0.892303
# 2           7                10  0.891695
# 3           7                15  0.891265
# 12         11                 1  0.889278
# 1           7                 2  0.886709
# 0           7                 1  0.886539

# %%
df_scores_pivot = df_scores.pivot_table(index='min_samples_leaf', 
                        columns='max_depth', 
                        values=['auc'])

# %%
sns.heatmap(df_scores_pivot, annot=True, fmt='.3f')
# Out:
# <Axes: xlabel='None-max_depth', ylabel='min_samples_leaf'>

# %%
dt = DecisionTreeClassifier(max_depth=10, min_samples_leaf=10)
dt.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(max_depth=10, min_samples_leaf=10)

# %% [markdown]
# ### Ensembles and Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf = RandomForestClassifier(n_estimators=10, random_state=1)
rf.fit(X_train, y_train)
# Out:
# RandomForestClassifier(n_estimators=10, random_state=1)

# %%
y_pred = rf.predict_proba(X_val)[:, 1]
roc_auc_score(y_val, y_pred)

# %%
rf.predict_proba(X_val[[0]])

# %%
scores = []
for n in range(20, 201, 5):
    rf = RandomForestClassifier(n_estimators=n, random_state=1)
    rf.fit(X_train, y_train)

    y_pred = rf.predict_proba(X_val)[:, 1]
    auc = roc_auc_score(y_val, y_pred)

    scores.append((n, auc))

# %%
df_scores = pd.DataFrame(scores, columns=['n_estimators', 'auc'])

# %%
plt.plot(df_scores.n_estimators, df_scores.auc)

# %% [markdown]
# ### Training Random Forest for different tree params

# %%
scores = []

for d in [7, 10, 11]:
    for n in range(20, 151, 10):
        rf = RandomForestClassifier(n_estimators=n,
                                    max_depth=d,
                                    random_state=1)
        rf.fit(X_train, y_train)

        y_pred = rf.predict_proba(X_val)[:, 1]
        auc = roc_auc_score(y_val, y_pred)
        scores.append((d, n, auc))

# %%
columns = ['max_depth', 'n_estimators', 'auc']
df_scores = pd.DataFrame(scores, columns=columns)
df_scores
# Out:
#     max_depth  n_estimators       auc
# 0           7            20  0.900830
# 1           7            30  0.901354
# 2           7            40  0.903146
# 3           7            50  0.902989
# 4           7            60  0.902893
# 5           7            70  0.902906
# 6           7            80  0.902880
# 7           7            90  0.903095
# 8           7           100  0.902857
# 9           7           110  0.902945
# 10          7           120  0.903016
# 11          7           130  0.903312
# 12          7           140  0.903208
# 13          7           150  0.903330
# 14         10            20  0.908130
# 15         10            30  0.907624
# 16         10            40  0.908394
# 17         10            50  0.908991
# 18         10            60  0.909253
# 19         10            70  0.909293
# 20         10            80  0.909123
# 21         10            90  0.909132
# 22         10           100  0.909057
# 23         10           110  0.909058
# 24         10           120  0.909310
# 25         10           130  0.909525
# 26         10           140  0.909685
# 27         10           150  0.909635
# 28         11            20  0.908740
# 29         11            30  0.908651
# 30         11            40  0.909918
# 31         11            50  0.910460
# 32         11            60  0.910408
# 33         11            70  0.910824
# 34         11            80  0.910886
# 35         11            90  0.910525
# 36         11           100  0.910339
# 37         11           110  0.910401
# 38         11           120  0.910369
# 39         11           130  0.910543
# 40         11           140  0.910498
# 41         11           150  0.910443

# %%
for d in [7, 10, 11]:
    df_subset = df_scores[df_scores.max_depth==d]
    plt.plot(df_subset.n_estimators, df_subset.auc, label='max_depth=%d' % d)

plt.legend()

# %%
max_depth = 11

# %%
scores = []

for s in [1, 3, 5, 10, 50]:
    for n in range(20, 151, 10):
        rf = RandomForestClassifier(n_estimators=n,
                                    max_depth=max_depth,
                                    min_samples_leaf=s,
                                    random_state=1)
        rf.fit(X_train, y_train)

        y_pred = rf.predict_proba(X_val)[:, 1]
        auc = roc_auc_score(y_val, y_pred)
        scores.append((s, n, auc))

# %%
columns = ['min_samples_leaf', 'n_estimators', 'auc']
df_scores = pd.DataFrame(scores, columns=columns)
df_scores
# Out:
#     min_samples_leaf  n_estimators       auc
# 0                  1            20  0.908740
# 1                  1            30  0.908651
# 2                  1            40  0.909918
# 3                  1            50  0.910460
# 4                  1            60  0.910408
# ..               ...           ...       ...
# 65                50           110  0.903079
# 66                50           120  0.903176
# 67                50           130  0.903470
# 68                50           140  0.903491
# 69                50           150  0.903670
#
# [70 rows x 3 columns]

# %%
colors = ['black', 'blue', 'orange', 'red', 'grey']
min_samples_leaf_values = [1, 3, 5, 10, 50]
for s, col in zip(min_samples_leaf_values, colors):
    df_subset = df_scores[df_scores.min_samples_leaf == s]
    plt.plot(df_subset.n_estimators, df_subset.auc,
            color = col,
            label = 'min_samples_leaf=%d' % s)

plt.legend()

# %%
n_estimators = 50
max_depth = 11
min_samples_leaf = 3

# %%
rf = RandomForestClassifier(n_estimators=50,
                                    max_depth=11,
                                    min_samples_leaf=3,
                                    n_jobs=4,
                                    random_state=1)
rf.fit(X_train, y_train)
# Out:
# RandomForestClassifier(max_depth=11, min_samples_leaf=3, n_estimators=50,
#                        n_jobs=4, random_state=1)

# %%
# !pip install xgboost
# Out:
# Collecting xgboost
#   Downloading xgboost-2.0.1-py3-none-manylinux2014_x86_64.whl (297.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 297.1/297.1 MB 4.1 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: numpy in /home/singh/anaconda3/lib/python3.10/site-packages (from xgboost) (1.23.5)
# Requirement already satisfied: scipy in /home/singh/anaconda3/lib/python3.10/site-packages (from xgboost) (1.10.0)
# Installing collected packages: xgboost
# Successfully installed xgboost-2.0.1

# %%
import xgboost as xgb

# %%
features = dv.feature_names_
dtrain = xgb.DMatrix(X_train, label=y_train, feature_names=features)
dval = xgb.DMatrix(X_val, label=y_val, feature_names=features)

# %%
dval = xgb.DMatrix(X_val, label=y_val, feature_names=features)

# %%
xgb_params = {
    'eta': 0.3,
    'max_depth': 6,
    'min_child_weight': 1,

    'objective': 'binary:logistic',
    'nthread': 8,

    'seed': 1,
    'verbosity': 1,
}

model = xgb.train(xgb_params, dtrain, num_boost_round=200)

# %%
y_pred = model.predict(dval)

# %%
roc_auc_score(y_val, y_pred)
# Out:
# 0.9238840461504477

# %%
watchlist = [(dtrain, 'train'), (dval, 'val')]

# %%
# %%capture output

xgb_params = {
    'eta': 0.3,
    'max_depth': 6,
    'min_child_weight': 1,

    'objective': 'binary:logistic',
    'eval_metric': 'auc',
    'nthread': 8,

    'seed': 1,
    'verbosity': 1,
}

model = xgb.train(xgb_params, dtrain, num_boost_round = 300, 
                    verbose_eval = 5,
                    evals = watchlist)

# %%
print(output.stdout)
# Out:
# [0]	train-auc:0.88177	val-auc:0.87830
# [5]	train-auc:0.91452	val-auc:0.90939
# [10]	train-auc:0.92300	val-auc:0.91725
# [15]	train-auc:0.92980	val-auc:0.92190
# [20]	train-auc:0.93374	val-auc:0.92321
# [25]	train-auc:0.93674	val-auc:0.92490
# [30]	train-auc:0.93871	val-auc:0.92553
# [35]	train-auc:0.94047	val-auc:0.92560
# [40]	train-auc:0.94187	val-auc:0.92601
# [45]	train-auc:0.94314	val-auc:0.92613
# [50]	train-auc:0.94407	val-auc:0.92629
# [55]	train-auc:0.94499	val-auc:0.92629
# [60]	train-auc:0.94579	val-auc:0.92619
# [65]	train-auc:0.94630	val-auc:0.92630
# [70]	train-auc:0.94704	val-auc:0.92643
# [75]	train-auc:0.94808	val-auc:0.92652
# [80]	train-auc:0.94874	val-auc:0.92630
# [85]	train-auc:0.94970	val-auc:0.92610
# [90]	train-auc:0.95046	val-auc:0.92627
# [95]	train-auc:0.95093	val-auc:0.92620
# [100]	train-auc:0.95140	val-auc:0.92605
# [105]	train-auc:0.95260	val-auc:0.92576
# [110]	train-auc:0.95333	val-auc:0.92567
# [115]	train-auc:0.95425	val-auc:0.92537
# [120]	train-auc:0.95501	val-auc:0.92532
# [125]	train-auc:0.95569	val-auc:0.92521
# [130]	train-auc:0.95619	val-auc:0.92505
# [135]	train-auc:0.95649	val-auc:0.92499
# [140]	train-auc:0.95667	val-auc:0.92498
# [145]	train-auc:0.95677	val-auc:0.92507
# [150]	train-auc:0.95722	val-auc:0.92484
# [155]	train-auc:0.95759	val-auc:0.92482
# [160]	train-auc:0.95805	val-auc:0.92469
# [165]	train-auc:0.95841	val-auc:0.92466
# [170]	train-auc:0.95852	val-auc:0.92460
# [175]	train-auc:0.95914	val-auc:0.92433
# [180]	train-auc:0.95923	val-auc:0.92432
# [185]	train-auc:0.95983	val-auc:0.92423
# [190]	train-auc:0.96073	val-auc:0.92393
# [195]	train-auc:0.96141	val-auc:0.92396
# [200]	train-auc:0.96168	val-auc:0.92382
# [205]	train-auc:0.96195	val-auc:0.92353
# [210]	train-auc:0.96213	val-auc:0.92357
# [215]	train-auc:0.96246	val-auc:0.92338
# [220]	train-auc:0.96356	val-auc:0.92320
# [225]	train-auc:0.96400	val-auc:0.92303
# [230]	train-auc:0.96475	val-auc:0.92270
# [235]	train-auc:0.96560	val-auc:0.92222
# [240]	train-auc:0.96607	val-auc:0.92223
# [245]	train-auc:0.96615	val-auc:0.92227
# [250]	train-auc:0.96648	val-auc:0.92216
# [255]	train-auc:0.96683	val-auc:0.92200
# [260]	train-auc:0.96731	val-auc:0.92171
# [265]	train-auc:0.96766	val-auc:0.92170
# [270]	train-auc:0.96794	val-auc:0.92173
# [275]	train-auc:0.96828	val-auc:0.92154
# [280]	train-auc:0.96879	val-auc:0.92133
# [285]	train-auc:0.96885	val-auc:0.92131
# [290]	train-auc:0.96893	val-auc:0.92124
# [295]	train-auc:0.96925	val-auc:0.92106
# [299]	train-auc:0.96941	val-auc:0.92093

# %%
s = output.stdout

# %%
def parse_xgb_output(output):
    results = []

    for line in output.stdout.strip().split('\n'):
        it_line, train_line, val_line =  line.split('\t')

        it = int(it_line.strip('[]'))
        train = float(train_line.split(':')[1])
        val = float(val_line.split(':')[1])

        results.append((it, train, val))

    columns = ['num_iter', 'train_auc', 'val_auc']
    df_results = pd.DataFrame(results, columns = columns)
    return df_results

# %%
df_score = parse_xgb_output(output)

# %%
# plt.plot(df_score.num_iter, df_score.train_auc, label='train')
plt.plot(df_score.num_iter, df_score.val_auc, label='val')
plt.legend()

# %% [markdown]
# ### Tuning XGB Params
# <ul>
# <li> learning rate (eta) </li>
# <li> max_depth </li>
# <li>min_child_weight</li>
# </ul>

# %%
scores = {}

# %%
# %%capture output

xgb_params = {
    'eta': 0.1,
    'max_depth': 10,
    'min_child_weight': 13,

    'objective': 'binary:logistic',
    'eval_metric': 'auc',
    'nthread': 8,

    'seed': 1,
    'verbosity': 1,
}

model = xgb.train(xgb_params, dtrain, num_boost_round = 300, 
                    verbose_eval = 5,
                    evals = watchlist)

# %% [markdown]
# df_score = parse_xgb_output(output)

# %%
key = 'min_child_weight=%s' % (xgb_params['min_child_weight'])
scores[key] = parse_xgb_output(output)
key
# Out:
# 'min_child_weight=13'

# %%
scores['eta=0.01']
# Out:
#     num_iter  train_auc  val_auc
# 0          0    0.88177  0.87830
# 1          5    0.88882  0.88297
# 2         10    0.89047  0.88433
# 3         15    0.89110  0.88476
# 4         20    0.89239  0.88687
# ..       ...        ...      ...
# 56       280    0.92073  0.91608
# 57       285    0.92104  0.91634
# 58       290    0.92136  0.91652
# 59       295    0.92161  0.91672
# 60       299    0.92178  0.91681
#
# [61 rows x 3 columns]

# %%
etas = ['eta=0.3', 'eta=0.1', 'eta=0.05']
for eta in etas:
    df_score = scores[eta]
    plt.plot(df_score.num_iter, df_score.val_auc, label=eta)
plt.legend()

# %%
eta = 0.1

# %%
mds = ['max_depth=11', 'max_depth=6', 'max_depth=10']
for md in mds:
    df_score = scores[md]
    plt.plot(df_score.num_iter, df_score.val_auc, label=md)
plt.ylim(0.9, 0.95)
plt.legend()

# %%
mcws = ['min_child_weight=1', 'min_child_weight=3', 'min_child_weight=13']
for mcw in mcws:
    df_score = scores[mcw]
    plt.plot(df_score.num_iter, df_score.val_auc, label=mcw)
plt.ylim(0.9, 0.95)
plt.legend()

# %% [markdown]
# ### Final XGB Model

# %%
eta = 0.1
max_depth = 10
min_child_weight = 1
num_boost_round = 150

# %%
xgb_params = {
    'eta': eta,
    'max_depth': max_depth,
    'min_child_weight': min_child_weight,

    'objective': 'binary:logistic',
    'eval_metric': 'auc',
    'nthread': 8,

    'seed': 1,
    'verbosity': 1,
}

model = xgb.train(xgb_params, dtrain, 
                    num_boost_round = num_boost_round, 
                    verbose_eval = 5,
                    evals = watchlist)
# Out:
# [0]	train-auc:0.91372	val-auc:0.90228
# [5]	train-auc:0.92471	val-auc:0.91000
# [10]	train-auc:0.93080	val-auc:0.91369
# [15]	train-auc:0.93585	val-auc:0.91735
# [20]	train-auc:0.93876	val-auc:0.91918
# [25]	train-auc:0.94109	val-auc:0.92151
# [30]	train-auc:0.94272	val-auc:0.92235
# [35]	train-auc:0.94402	val-auc:0.92302
# [40]	train-auc:0.94555	val-auc:0.92382
# [45]	train-auc:0.94645	val-auc:0.92427
# [50]	train-auc:0.94825	val-auc:0.92435
# [55]	train-auc:0.94981	val-auc:0.92451
# [60]	train-auc:0.95062	val-auc:0.92468
# [65]	train-auc:0.95141	val-auc:0.92485
# [70]	train-auc:0.95248	val-auc:0.92537
# [75]	train-auc:0.95322	val-auc:0.92556
# [80]	train-auc:0.95385	val-auc:0.92578
# [85]	train-auc:0.95435	val-auc:0.92587
# [90]	train-auc:0.95519	val-auc:0.92571
# [95]	train-auc:0.95564	val-auc:0.92578
# [100]	train-auc:0.95640	val-auc:0.92569
# [105]	train-auc:0.95666	val-auc:0.92579
# [110]	train-auc:0.95711	val-auc:0.92587
# [115]	train-auc:0.95748	val-auc:0.92583
# [120]	train-auc:0.95795	val-auc:0.92589
# [125]	train-auc:0.95853	val-auc:0.92565
# [130]	train-auc:0.95897	val-auc:0.92564
# [135]	train-auc:0.95932	val-auc:0.92560
# [140]	train-auc:0.95958	val-auc:0.92561
# [145]	train-auc:0.96000	val-auc:0.92549
# [149]	train-auc:0.96040	val-auc:0.92546

# %% [markdown]
# #### Selecting the final model

# %%
dt = DecisionTreeClassifier(max_depth=10, min_samples_leaf=10)
dt.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(max_depth=10, min_samples_leaf=10)

# %%
rf = RandomForestClassifier(n_estimators=50,
                                    max_depth=11,
                                    min_samples_leaf=3,
                                    n_jobs=4,
                                    random_state=1)
rf.fit(X_train, y_train)
# Out:
# RandomForestClassifier(max_depth=11, min_samples_leaf=3, n_estimators=50,
#                        n_jobs=4, random_state=1)

# %%
eta = 0.1
max_depth = 10
min_child_weight = 1
num_boost_round = 150

xgb_params = {
    'eta': eta,
    'max_depth': max_depth,
    'min_child_weight': min_child_weight,

    'objective': 'binary:logistic',
    'eval_metric': 'auc',
    'nthread': 8,

    'seed': 1,
    'verbosity': 1,
}

model = xgb.train(xgb_params, dtrain, 
                    num_boost_round = num_boost_round)

# %%
y_pred = dt.predict_proba(X_val)[:, 1]
roc_auc_score(y_val, y_pred)
# Out:
# 0.8988607406548038

# %%
y_pred = rf.predict_proba(X_val)[:, 1]
roc_auc_score(y_val, y_pred)
# Out:
# 0.9108536227374919

# %%
y_pred = model.predict(dval)
roc_auc_score(y_val, y_pred)
# Out:
# 0.9254574966938716

# %% [markdown]
# ### Using full train data on XGBoost model

# %%
df_full_train
# Out:
#        age         workclass  fnlwgt   education  education_num  \
# 0       39         state_gov   77516   bachelors             13
# 1       50  self_emp_not_inc   83311   bachelors             13
# 2       38           private  215646     hs_grad              9
# 3       53           private  234721        11th              7
# 4       28           private  338409   bachelors             13
# ...    ...               ...     ...         ...            ...
# 32556   27           private  257302  assoc_acdm             12
# 32557   40           private  154374     hs_grad              9
# 32558   58           private  151910     hs_grad              9
# 32559   22           private  201490     hs_grad              9
# 32560   52      self_emp_inc  287927     hs_grad              9
#
#            marital_status         occupation   relationship   race     sex  \
# 0           never_married       adm_clerical  not_in_family  white    male
# 1      married_civ_spouse    exec_managerial        husband  white    male
# 2                divorced  handlers_cleaners  not_in_family  white    male
# 3      married_civ_spouse  handlers_cleaners        husband  black    male
# 4      married_civ_spouse     prof_specialty           wife  black  female
# ...                   ...                ...            ...    ...     ...
# 32556  married_civ_spouse       tech_support           wife  white  female
# 32557  married_civ_spouse  machine_op_inspct        husband  white    male
# 32558             widowed       adm_clerical      unmarried  white  female
# 32559       never_married       adm_clerical      own_child  white    male
# 32560  married_civ_spouse    exec_managerial           wife  white  female
#
#        capital_gain  capital_loss  hours_per_week native_country income  \
# 0              2174             0              40  united_states  <=50k
# 1                 0             0              13  united_states  <=50k
# 2                 0             0              40  united_states  <=50k
# 3                 0             0              40  united_states  <=50k
# 4                 0             0              40           cuba  <=50k
# ...             ...           ...             ...            ...    ...
# 32556             0             0              38  united_states  <=50k
# 32557             0             0              40  united_states   >50k
# 32558             0             0              40  united_states  <=50k
# 32559             0             0              20  united_states  <=50k
# 32560         15024             0              40  united_states   >50k
#
#        income>50k
# 0               0
# 1               0
# 2               0
# 3               0
# 4               0
# ...           ...
# 32556           0
# 32557           1
# 32558           0
# 32559           0
# 32560           1
#
# [30162 rows x 16 columns]

# %%
y_full_train = df_full_train['income>50k'].values

# %%
del df_full_train['income']

del df_full_train['income>50k']

del df_full_train['fnlwgt']

# %%
dicts_full_train = df_full_train[numerical + categorical].to_dict(orient='records')

dv = DictVectorizer(sparse=False)
X_full_train = dv.fit_transform(dicts_full_train)

dicts_test = df_test[categorical + numerical].to_dict(orient='records')
X_test = dv.transform(dicts_test)

# %%
dfulltrain = xgb.DMatrix(X_full_train, 
                    label=y_full_train, 
                    feature_names=dv.feature_names_)

dtest = xgb.DMatrix(X_test, 
                    feature_names=dv.feature_names_)

# %%
eta = 0.1
max_depth = 10
min_child_weight = 1
num_boost_round = 150

xgb_params = {
    'eta': eta,
    'max_depth': max_depth,
    'min_child_weight': min_child_weight,

    'objective': 'binary:logistic',
    'eval_metric': 'auc',
    'nthread': 8,

    'seed': 1,
    'verbosity': 1,
}

model = xgb.train(xgb_params, dfulltrain, 
                    num_boost_round = num_boost_round)

# %%
y_pred = model.predict(dtest)

# %%
y_pred[:10]
# Out:
# array([7.9376053e-04, 1.5819095e-01, 3.7271968e-01, 9.9865282e-01,
#        3.0083177e-03, 9.8209149e-01, 5.1143700e-03, 3.0222986e-02,
#        9.5359921e-01, 6.4575040e-01], dtype=float32)

# %%
roc_auc_score(y_test, y_pred)
# Out:
# 0.9257197135515799
